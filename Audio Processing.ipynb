# %%
import os, sys
import pathlib
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D, BatchNormalization, Activation
from tensorflow.keras.layers.experimental.preprocessing import Resizing, Normalization
physical_devices = tf.config.experimental.list_physical_devices('GPU')
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
print(f'Running on Python {sys.version}, Tensorflow {tf.__version__}.')
# Out:
# Running on Python 3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)], Tensorflow 2.5.0.

# %%
seed = 69
AUTOTUNE = tf.data.AUTOTUNE
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
data_dir = pathlib.Path('data/mini_speech_commands')
labels = np.array(tf.io.gfile.listdir(str(data_dir)))
labels = labels[labels != 'README.md']
print('Commands:', labels)
# Out:
# Commands: ['down' 'go' 'left' 'no' 'right' 'stop' 'up' 'yes']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:', len(tf.io.gfile.listdir(str(data_dir/labels[0]))))
print('Example file tensor:', filenames[0])

train_files = filenames[:round(num_samples*0.8)]  # first 80%
val_files = filenames[round(num_samples*0.8): round(num_samples*0.8) + round(num_samples*0.1)]  # 80% to 90%
test_files = filenames[-round(num_samples*0.1):]  # last 10 %

print('Training set size', len(train_files))
print('Validation set size', len(val_files))
print('Test set size', len(test_files))
# Out:
# Number of total examples: 8000
# Number of examples per label: 1000
# Example file tensor: tf.Tensor(b'data\\mini_speech_commands\\no\\af130f12_nohash_1.wav', shape=(), dtype=string)
# Training set size 6400
# Validation set size 800
# Test set size 800

# %%
def get_waveform_and_label(file_path):
    audio, _ = tf.audio.decode_wav(tf.io.read_file(file_path))
    waveform = tf.squeeze(audio, axis=-1)
    parts = tf.strings.split(file_path, os.path.sep)
    label = parts[-2]
    return waveform, label

train_ds = tf.data.Dataset.from_tensor_slices(train_files)
train_ds = train_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)

# %%
def plot_multiple_waveform(ds):
    rows = 3
    cols = 3
    n = rows*cols
    fig, axes = plt.subplots(rows, cols, figsize=(10, 12))
    for i, (audio, label) in enumerate(ds.take(n)):
      r = i // cols
      c = i % cols
      ax = axes[r][c]
      ax.plot(audio.numpy())
      ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
      label = label.numpy().decode('utf-8')
      ax.set_title(label)
    plt.show()

plot_multiple_waveform(train_ds)

def plot_multiple_spectrogram(ds):
    rows = 3
    cols = 3
    n = rows*cols
    fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
    for i, (spectrogram, label_id) in enumerate(ds.take(n)):
      r = i // cols
      c = i % cols
      ax = axes[r][c]
      plot_spectrogram(np.squeeze(spectrogram.numpy()), ax)
      ax.set_title(labels[label_id.numpy()])
      ax.axis('off')
    plt.show()

# %%
def get_spectrogram(waveform):
    # Padding for files with less than 16000 samples
    zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)
    # Concatenate audio with padding so that all audio clips will be of the same length
    waveform = tf.cast(waveform, tf.float32)
    equal_length = tf.concat([waveform, zero_padding], 0)
    # Choose frame_length and frame_step parameters such that the generated spectrogram "image" is almost square.
    spectrogram = tf.signal.stft(equal_length, frame_length=255, frame_step=123)
    spectrogram = tf.abs(spectrogram)
    return spectrogram

for waveform, label in train_ds.take(1):
    label = label.numpy().decode('utf-8')
    spectrogram = get_spectrogram(waveform)
    print('Label:', label)
    print('Waveform shape:', waveform.shape)
    print('Spectrogram shape (make this square):', spectrogram.shape)
    img_height, img_width = spectrogram.shape
    print('Audio playback')
    display.display(display.Audio(waveform, rate=16000))

def plot_spectrogram(spectrogram, ax):
  log_spec = np.log(spectrogram.T)
  height = log_spec.shape[0]
  width = log_spec.shape[1]
  X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
  Y = range(height)
  ax.pcolormesh(X, Y, log_spec, shading='auto')

fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, 16000])
plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.show()

def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  spectrogram = tf.expand_dims(spectrogram, -1)
  # spectrogram = tf.image.resize(spectrogram, [64, 64])
  # spectrogram = tf.image.grayscale_to_rgb(spectrogram)  # RGB if using pretrained network that is trained on RGB images e.g. ImageNet, else can gray scale
  label_id = tf.argmax(label == labels)
  return spectrogram, label_id

def preprocess_dataset(files):
  files_ds = tf.data.Dataset.from_tensor_slices(files)
  output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
  output_ds = output_ds.map(get_spectrogram_and_label_id,  num_parallel_calls=AUTOTUNE)
  return output_ds

train_ds = train_ds.map(get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)
plot_multiple_spectrogram(train_ds)
# Out:
# Label: no
# Waveform shape: (16000,)
# Spectrogram shape (make this square): (129, 129)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <ipython-input-7-912987be00bc>:24: RuntimeWarning: divide by zero encountered in log
#   log_spec = np.log(spectrogram.T)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size).cache().prefetch(AUTOTUNE)
val_ds = val_ds.batch(batch_size).cache().prefetch(AUTOTUNE)
test_ds = test_ds.batch(batch_size).cache().prefetch(AUTOTUNE)

input_shape = (img_height, img_width, 1)
print('Input shape:', input_shape)
num_labels = len(labels)
norm_layer = Normalization()
norm_layer.adapt(train_ds.map(lambda x, _: x))

xInput = layers.Input(input_shape)
x = Resizing(64, 64)(xInput)
x = norm_layer(x)
x = Conv2D(64, 3)(x)
x = BatchNormalization(epsilon=1.001e-5)(x)
x = Activation('relu')(x)
x = Conv2D(128, 3)(x)
x = BatchNormalization(epsilon=1.001e-5)(x)
x = Activation('relu')(x)
x = Conv2D(256, 3)(x)
x = BatchNormalization(epsilon=1.001e-5)(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
xOutput = Dense(num_labels)(x)  # no activation as using logits for loss

model = Model(xInput, xOutput)
model.summary()
# Out:
# Input shape: (129, 129, 1)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 129, 129, 1)]     0
# _________________________________________________________________
# resizing (Resizing)          (None, 64, 64, 1)         0
# _________________________________________________________________
# normalization (Normalization (None, 64, 64, 1)         3
# _________________________________________________________________
# conv2d (Conv2D)              (None, 62, 62, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 62, 62, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 62, 62, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 60, 60, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 60, 60, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 58, 58, 256)       295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 58, 58, 256)       1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 58, 58, 256)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 29, 29, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 215296)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               110232064
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 4104
# =================================================================
# Total params: 110,607,627
# Trainable params: 110,606,728
# Non-trainable params: 899
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(learning_rate=3e-4, epsilon=1e-6)
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = ['accuracy']
epoch = 100
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1,
                                     mode='auto', baseline=None, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('./best_model',monitor='val_accuracy',save_best_only=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=4, verbose=1)
]
model.compile(optimizer=opt, loss=loss, metrics=metrics)
plot_model(model, show_shapes=True, show_dtype=True, show_layer_names=True, to_file='audio_model.png')

# %%
history = model.fit(train_ds, epochs=epoch, validation_data=val_ds, callbacks=callbacks, use_multiprocessing=True, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 12s 88ms/step - loss: 3.7005 - accuracy: 0.1775 - val_loss: 2.0450 - val_accuracy: 0.1700
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 2/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.9274 - accuracy: 0.2348 - val_loss: 1.9323 - val_accuracy: 0.2750
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 3/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.7701 - accuracy: 0.2981 - val_loss: 1.7521 - val_accuracy: 0.3200
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 4/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.6552 - accuracy: 0.3520 - val_loss: 1.5003 - val_accuracy: 0.4613
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 5/100
# 100/100 [==============================] - 8s 83ms/step - loss: 1.4864 - accuracy: 0.4136 - val_loss: 1.3183 - val_accuracy: 0.5550
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 6/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.3182 - accuracy: 0.4716 - val_loss: 1.0347 - val_accuracy: 0.6325
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 7/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.1945 - accuracy: 0.5223 - val_loss: 0.9366 - val_accuracy: 0.6762
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 8/100
# 100/100 [==============================] - 8s 84ms/step - loss: 1.0891 - accuracy: 0.5541 - val_loss: 0.8203 - val_accuracy: 0.7063
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 9/100
#  - ETA: 5s - loss: 0.9939 - accuracy: 0.5881
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 10/100
# 100/100 [==============================] - 9s 88ms/step - loss: 0.9615 - accuracy: 0.6041 - val_loss: 0.7512 - val_accuracy: 0.7337
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 11/100
# 100/100 [==============================] - 9s 85ms/step - loss: 0.9162 - accuracy: 0.6217 - val_loss: 0.6970 - val_accuracy: 0.7575
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 12/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.8560 - accuracy: 0.6486 - val_loss: 0.7234 - val_accuracy: 0.7250
# Epoch 13/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.8149 - accuracy: 0.6716 - val_loss: 0.6713 - val_accuracy: 0.7600
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 14/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.7786 - accuracy: 0.6859 - val_loss: 0.8822 - val_accuracy: 0.6650
# Epoch 15/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.7403 - accuracy: 0.7077 - val_loss: 0.6900 - val_accuracy: 0.7588
# Epoch 16/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.7072 - accuracy: 0.7230 - val_loss: 0.5924 - val_accuracy: 0.8012
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 17/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.6828 - accuracy: 0.7292 - val_loss: 0.5817 - val_accuracy: 0.7862
# Epoch 18/100
# 100/100 [==============================] - 9s 85ms/step - loss: 0.6217 - accuracy: 0.7508 - val_loss: 0.6424 - val_accuracy: 0.7875
# Epoch 19/100
#  - ETA: 2s - loss: 0.5872 - accuracy: 0.7656
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.000000142492354e-05.
# Epoch 20/100
# 100/100 [==============================] - 9s 87ms/step - loss: 0.5561 - accuracy: 0.7767 - val_loss: 0.4961 - val_accuracy: 0.8438
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 21/100
# 100/100 [==============================] - 9s 86ms/step - loss: 0.5093 - accuracy: 0.7884 - val_loss: 0.5083 - val_accuracy: 0.8313
# Epoch 22/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.5116 - accuracy: 0.7847 - val_loss: 0.4944 - val_accuracy: 0.8363
# Epoch 23/100
# 100/100 [==============================] - 9s 89ms/step - loss: 0.4925 - accuracy: 0.7931 - val_loss: 0.4817 - val_accuracy: 0.8438
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-06.
# Epoch 24/100
# 100/100 [==============================] - 9s 86ms/step - loss: 0.4893 - accuracy: 0.8008 - val_loss: 0.4737 - val_accuracy: 0.8512
# INFO:tensorflow:Assets written to: .\best_model\assets
# Epoch 25/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.4766 - accuracy: 0.8072 - val_loss: 0.4698 - val_accuracy: 0.8500
# Epoch 26/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4705 - accuracy: 0.8066 - val_loss: 0.4702 - val_accuracy: 0.8500
# Epoch 27/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4651 - accuracy: 0.8100 - val_loss: 0.4672 - val_accuracy: 0.8500
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-07.
# Epoch 28/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4626 - accuracy: 0.8122 - val_loss: 0.4669 - val_accuracy: 0.8500
# Epoch 29/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.4632 - accuracy: 0.8106 - val_loss: 0.4671 - val_accuracy: 0.8500
# Epoch 30/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.4442 - accuracy: 0.8164 - val_loss: 0.4672 - val_accuracy: 0.8487
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-08.
# Epoch 31/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4616 - accuracy: 0.8117 - val_loss: 0.4673 - val_accuracy: 0.8500
# Epoch 32/100
# 100/100 [==============================] - 8s 85ms/step - loss: 0.4684 - accuracy: 0.8086 - val_loss: 0.4673 - val_accuracy: 0.8487
# Epoch 33/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4821 - accuracy: 0.7997 - val_loss: 0.4673 - val_accuracy: 0.8487
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.000000248221113e-09.
# Epoch 34/100
# 100/100 [==============================] - 8s 84ms/step - loss: 0.4562 - accuracy: 0.8192 - val_loss: 0.4673 - val_accuracy: 0.8487
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping

# %%
model.evaluate(test_ds)
model.save('mini_voice_classification')
# Out:
# 13/13 [==============================] - 1s 41ms/step - loss: 0.4338 - accuracy: 0.8662
# INFO:tensorflow:Assets written to: mini_voice_classification\assets

# %%
file_to_predict = data_dir/'stop/0ff728b5_nohash_4.wav'
display.display(display.Audio(file_to_predict))
to_predict_ds = preprocess_dataset([str(file_to_predict)])

for spectrogram, label in to_predict_ds.batch(1):
    prediction = model(spectrogram)
    plt.bar(labels, tf.nn.softmax(prediction[0]))
    plt.title(f'Predictions for "{labels[label[0]]}"')
    plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
