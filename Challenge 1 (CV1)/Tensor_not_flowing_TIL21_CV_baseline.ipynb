# %% [markdown]
# ## Downloading Dependencies

# %%
# First, we need to install pycocotools. This library will be used for computing the evaluation metrics following the COCO metric for intersection over union.
# The version by default in Colab has a bug fixed in https://github.com/cocodataset/cocoapi/pull/354
# !pip install cython
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !nvidia-smi
# Out:
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (0.29.23)
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-uijo792f
#   Running command git clone -q https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-uijo792f
# Requirement already satisfied, skipping upgrade: setuptools>=18.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (57.0.0)
# Requirement already satisfied, skipping upgrade: cython>=0.27.3 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (0.29.23)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pycocotools==2.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools==2.0) (1.15.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=263906 sha256=cf6a08709c74a7b51ba8e0af6948be11b1bb5391cf3cb5a2dfc24c899cb10828
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rhkgdzgs/wheels/90/51/41/646daf401c3bc408ff10de34ec76587a9b3ebfac8d21ca5c3a
# Successfully built pycocotools
# Installing collected packages: pycocotools
#   Found existing installation: pycocotools 2.0
#     Uninstalling pycocotools-2.0:
#       Successfully uninstalled pycocotools-2.0
# Successfully installed pycocotools-2.0
# Mon Jun 14 16:50:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import json
import math
import os
import random
import sys
import time

import numpy as np
import torch
import torch.utils.data
import torchvision

from PIL import Image, ImageDraw
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from torchvision import transforms
from torchvision.ops import batched_nms
from torchvision.transforms import functional as F

# %%
from typing import List, Tuple

import torchvision.models as models

from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection.faster_rcnn import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.ops import MultiScaleRoIAlign

# %% [markdown]
# In `references/detection/,` we have a number of helper functions to simplify training and evaluating detection models.
# Here, we will use `references/detection/utils.py` and `references/detection/coco_eval.py`.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/coco_eval.py ../
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
import utils
from coco_eval import CocoEvaluator

# %%
# check if cuda GPU is available, make sure you're using GPU runtime on Google Colab
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device) # you should output "cuda"
# Out:
# cuda

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Object Detection Dataset
# We will be providing the base dataset that will be used for the first task of the Object Detection competition.

# %%
# You should have uploaded the training dataset onto your google drive.

base_folder = '/content/drive/MyDrive/TIL2021' # Change this path to your folder for this competition
training_path = os.path.join(base_folder, "c1_release.zip") # zip file for training dataset

# %%
# unzip the training dataset
# !unzip $training_path
# Out:
# Archive:  /content/drive/MyDrive/TIL2021/c1_release.zip
# replace TIL/CREDITS.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace TIL/images/0001e6adc4fbab0c.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# Let's have a look at the dataset and how it is layed down.
#
# The data is structured as follows
# ```
# c1_release/
#   images/
#     0001e6adc4fbab0c.jpg
#     00067fe83e3e21c8.jpg
#     0008ab3d8674f6ca.jpg
#     ...
#   labels.json
#   train.json
#   val.json
# ```
#
# `labels.json` contains the labels for the whole dataset (`train.json` + `val.json`) if you need it.

# %% [markdown]
# ### Defining the Dataset
#
# The [torchvision reference scripts for training object detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
# Additionally, if you want to use aspect ratio grouping during training (so that each batch only contains images with similar aspect ratio), then it is recommended to also implement a `get_height_and_width` method, which returns the height and the width of the image. If this method is not provided, we query all elements of the dataset via `__getitem__` , which loads the image in memory and is slower than if a custom method is provided.
#
# Let's write a `torch.utils.data.Dataset` class for this dataset.

# %%
class TILDataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation, transforms=None):
        self.root = root
        self.transforms = transforms
        self.coco = COCO(annotation)
        self.ids = list(sorted(self.coco.imgs.keys()))
        cats = self.coco.loadCats(self.coco.getCatIds())
        self.cat2name = {cat['id']:cat['name'] for cat in cats} # maps category id to category name (useful for visualization)

    def __getitem__(self, index):
        coco = self.coco
        img_id = self.ids[index] # Image ID
        ann_ids = coco.getAnnIds(imgIds=img_id) # get annotation id from coco
        coco_annotation = coco.loadAnns(ann_ids) # target coco_annotation file for an image
        path = coco.loadImgs(img_id)[0]['file_name'] # path for input image
        img = Image.open(os.path.join(self.root, 'images', path)).convert('RGB') # open the input image

        # number of objects in the image
        num_objs = len(coco_annotation)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        for i in range(num_objs):
            xmin = coco_annotation[i]['bbox'][0]
            ymin = coco_annotation[i]['bbox'][1]
            xmax = xmin + coco_annotation[i]['bbox'][2]
            ymax = ymin + coco_annotation[i]['bbox'][3]
            boxes.append([xmin, ymin, xmax, ymax])
        boxes = torch.as_tensor(boxes, dtype=torch.float32)

        # Labels
        labels = []
        for i in range(num_objs):
            labels.append(coco_annotation[i]['category_id'])
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Tensorise img_id
        img_id = torch.tensor([img_id])

        # Size of bbox (Rectangular)
        areas = []
        for i in range(num_objs):
            areas.append(coco_annotation[i]['area'])
        areas = torch.as_tensor(areas, dtype=torch.float32)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        target["area"] = areas
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.ids)

# %% [markdown]
# That's all for the dataset. Let's see how the outputs are structured for this dataset

# %%
til_root = "/content/TIL/" # extracted training dataset path
train_annotation = os.path.join(til_root, "train.json")
val_annotation = os.path.join(til_root, "val.json")

dataset = TILDataset(til_root, train_annotation)
dataset[30]
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# (<PIL.Image.Image image mode=RGB size=1024x683 at 0x7FE6FC59F710>,
#  {'area': tensor([ 77211., 309760.]),
#   'boxes': tensor([[658., 309., 865., 682.],
#           [ 69., 170., 674., 682.]]),
#   'image_id': tensor([31]),
#   'iscrowd': tensor([0, 0]),
#   'labels': tensor([4, 4])})

# %% [markdown]
# So we can see that by default, the dataset returns a `PIL.Image` and a dictionary containing several fields, including `boxes` and `labels`.
#
# Let's next look at one example from the training set.

# %%
source_img, img_annots = dataset[30]
draw = ImageDraw.Draw(source_img)
for i in range(len(img_annots["boxes"])):
    x1, y1, x2, y2 = img_annots["boxes"][i]
    label = int(img_annots["labels"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}'
    draw.text((x1+5, y1+5), text)
display(source_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7FE6FC59F990>

# %% [markdown]
# ## Setting up the Model
#
# In this object detection example, we will make use of Faster R-CNN model with a ResNet50-FPN backbone. To understand the underlying code structure, you can read this [article](https://zhuanlan.zhihu.com/p/145842317) (right click and translate to English).
#
# Feel free to explore with different hyper-parameters to see what works best!

# %%
# hyper-parameters
params = {'BATCH_SIZE': 8,
          'LR': 0.005,
          'CLASSES': 6,
          'MAXEPOCHS': 20,
          'BACKBONE': 'resnet152',
          'FPN': True,
          'ANCHOR_SIZE': ((32,), (64,), (128,), (256,), (512,)),
          'ASPECT_RATIOS': ((0.5, 1.0, 2.0),),
          'MIN_SIZE': 512,
          'MAX_SIZE': 512,
          'IMG_MEAN': [0.485, 0.456, 0.406],
          'IMG_STD': [0.229, 0.224, 0.225],
          'IOU_THRESHOLD': 0.5
          }

# %%
def get_resnet_backbone(backbone_name: str):
    """
    Returns a resnet backbone pretrained on ImageNet.
    Removes the average-pooling layer and the linear layer at the end.
    """
    if backbone_name == 'resnet18':
        pretrained_model = models.resnet18(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet34':
        pretrained_model = models.resnet34(pretrained=True, progress=False)
        out_channels = 512
    elif backbone_name == 'resnet50':
        pretrained_model = models.resnet50(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet101':
        pretrained_model = models.resnet101(pretrained=True, progress=False)
        out_channels = 2048
    elif backbone_name == 'resnet152':
        pretrained_model = models.resnet152(pretrained=True, progress=False)
        out_channels = 2048

    backbone = torch.nn.Sequential(*list(pretrained_model.children())[:-2])
    backbone.out_channels = out_channels

    return backbone

# %%
def get_resnet_fpn_backbone(backbone_name: str):
    """
    Returns a specified ResNet backbone with FPN pretrained on ImageNet.
    """
    return resnet_fpn_backbone(backbone_name, pretrained=True, trainable_layers=3)

# %%
def get_anchor_generator(anchor_size: Tuple[tuple] = None, aspect_ratios: Tuple[tuple] = None):
    """Returns the anchor generator."""
    if anchor_size is None:
        anchor_size = ((16,), (32,), (64,), (128,))
    if aspect_ratios is None:
        aspect_ratios = ((0.5, 1.0, 2.0),) * len(anchor_size)

    anchor_generator = AnchorGenerator(sizes=anchor_size,
                                       aspect_ratios=aspect_ratios)
    return anchor_generator

# %%
def get_roi_pool(featmap_names: List[str] = None, output_size: int = 7, sampling_ratio: int = 2):
    """Returns the ROI Pooling"""
    if featmap_names is None:
        # default for resnet with FPN
        featmap_names = ['0', '1', '2', '3']

    roi_pooler = MultiScaleRoIAlign(featmap_names=featmap_names,
                                    output_size=output_size,
                                    sampling_ratio=sampling_ratio)

    return roi_pooler

# %%
def get_fasterRCNN(backbone: torch.nn.Module,
                   anchor_generator: AnchorGenerator,
                   roi_pooler: MultiScaleRoIAlign,
                   num_classes: int,
                   image_mean: List[float] = [0.485, 0.456, 0.406],
                   image_std: List[float] = [0.229, 0.224, 0.225],
                   min_size: int = 512,
                   max_size: int = 1024,
                   **kwargs
                   ):
    """Returns the Faster-RCNN model. Default normalization: ImageNet"""
    model = FasterRCNN(backbone=backbone,
                       rpn_anchor_generator=anchor_generator,
                       box_roi_pool=roi_pooler,
                       num_classes=num_classes,
                       image_mean=image_mean,  # ImageNet
                       image_std=image_std,  # ImageNet
                       min_size=min_size,
                       max_size=max_size,
                       **kwargs
                       )
    model.num_classes = num_classes
    model.image_mean = image_mean
    model.image_std = image_std
    model.min_size = min_size
    model.max_size = max_size

    return model

# %%
def get_fasterRCNN_resnet(num_classes: int,
                          backbone_name: str,
                          anchor_size: List[float],
                          aspect_ratios: List[float],
                          fpn: bool = True,
                          min_size: int = 512,
                          max_size: int = 1024,
                          **kwargs
                          ):
    """Returns the Faster-RCNN model with resnet backbone with and without fpn."""

    # Backbone
    if fpn:
        backbone = get_resnet_fpn_backbone(backbone_name=backbone_name)
    else:
        backbone = get_resnet_backbone(backbone_name=backbone_name)

    # Anchors
    anchor_size = anchor_size
    aspect_ratios = aspect_ratios * len(anchor_size)
    anchor_generator = get_anchor_generator(anchor_size=anchor_size, aspect_ratios=aspect_ratios)

    # ROI Pool
    with torch.no_grad():
        backbone.eval()
        random_input = torch.rand(size=(1, 3, 512, 512))
        features = backbone(random_input)

    if isinstance(features, torch.Tensor):
        from collections import OrderedDict

        features = OrderedDict([('0', features)])

    featmap_names = [key for key in features.keys() if key.isnumeric()]

    roi_pool = get_roi_pool(featmap_names=featmap_names)

    # Model
    return get_fasterRCNN(backbone=backbone,
                          anchor_generator=anchor_generator,
                          roi_pooler=roi_pool,
                          num_classes=num_classes,
                          min_size=min_size,
                          max_size=max_size,
                          **kwargs)

# %%
model = get_fasterRCNN_resnet(num_classes=params['CLASSES'],
                              backbone_name=params['BACKBONE'],
                              anchor_size=params['ANCHOR_SIZE'],
                              aspect_ratios=params['ASPECT_RATIOS'],
                              fpn=params['FPN'],
                              min_size=params['MIN_SIZE'],
                              max_size=params['MAX_SIZE'],
                              image_mean=params['IMG_MEAN'],
                              image_std=params['IMG_STD'])

# %%
# load pretrained weights for FasterRCNN ResNet50 FPN
pretrained_dict = torch.hub.load_state_dict_from_url('https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth', progress=True)
model_dict = model.state_dict()

# filter out roi_heads.box_predictor weights
pretrained_dict = {k: v for k, v in pretrained_dict.items() if not k.startswith('roi_heads.box_predictor')}
# overwrite entries in the existing state dict
model_dict.update(pretrained_dict)
# load the new state dict
model.load_state_dict(model_dict)
# Out:
# <All keys matched successfully>

# %%
# move model to the right device
model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(512,), max_size=512, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (7): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (6): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (7): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (8): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (9): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (10): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (11): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (12): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (13): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (14): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (15): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (16): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (17): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (18): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (19): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (20): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (21): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (22): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (23): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (24): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (25): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (26): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (27): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (28): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (29): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (30): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (31): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (32): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (33): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (34): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (35): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )

# %%
# construct an optimizer
model_params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(model_params, 
                            lr=params['LR'],
                            momentum=0.9, 
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=4,
                                               gamma=0.05)

# %% [markdown]
# ## Data Augmentation
#
# Let's write some helper functions for data augmentation / transformation.
#
# Do not just stop here, add in your own data augmentations! Remember to also augment the bounding boxes accordingly.

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target

# %%
# converts the image, a PIL image, into a PyTorch Tensor
class ToTensor(object):
    def __call__(self, image, target):
        image = F.to_tensor(image)
        return image, target

# %%
# randomly horizontal flip the images and ground-truth labels
class RandomHorizontalFlip(object):
    def __init__(self, prob):
        self.prob = prob

    def __call__(self, image, target):
        if random.random() < self.prob:
            height, width = image.shape[-2:]
            image = image.flip(-1)
            bbox = target["boxes"]
            bbox[:, [0, 2]] = width - bbox[:, [2, 0]]
            target["boxes"] = bbox
        return image, target

# %%
def get_transform(train):
    if train:
        transforms = Compose([
            ToTensor(), 
            RandomHorizontalFlip(0.5)
        ])
    else: # during evaluation, no augmentations will be done
        transforms = Compose([
            ToTensor()
        ])
    
    return transforms

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled by the R-CNN model.

# %% [markdown]
# ## Data Loaders
#
# Let's now set up our data loaders so that we can streamline the batch loading of data for our model training later on.
#
# We now have the dataset class, the models and the data transforms. Let's instantiate them

# %%
NUM_WORKERS = 4

# use our dataset and defined transformations
train_dataset = TILDataset(til_root, train_annotation, get_transform(train=True))
val_dataset = TILDataset(til_root, val_annotation, get_transform(train=False))

# define training and validation data loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=params['BATCH_SIZE'], shuffle=True, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)

val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=1, shuffle=False, num_workers=NUM_WORKERS,
    collate_fn=utils.collate_fn)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## Model Training
#
# And now let's train the model, evaluating at the end of every epoch.

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = utils.MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', utils.SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = utils.warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        loss_value = losses.item()

        if not math.isfinite(loss_value):
            print("Loss is {}, stopping training".format(loss_value))
            print(loss_dict)
            sys.exit(1)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses, **loss_dict)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

# %%
@torch.no_grad()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    torch.set_num_threads(1)
    model.eval()
    metric_logger = utils.MetricLogger(delimiter="  ")
    header = 'Test:'

    coco = data_loader.dataset.coco
    iou_types = ["bbox"]
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for image, targets in metric_logger.log_every(data_loader, 100, header):
        image = list(img.to(device) for img in image)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(image)

        outputs = [{k: v for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluator_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    return coco_evaluator

# %%
for epoch in range(params['MAXEPOCHS']):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10)

    # update the learning rate
    lr_scheduler.step()

    # evaluate on the test dataset
    evaluate(model, val_loader, device=device)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: [0]  [  0/589]  eta: 0:35:40  lr: 0.000003  loss: 1.7389 (1.7389)  loss_classifier: 1.5418 (1.5418)  loss_box_reg: 0.1533 (0.1533)  loss_objectness: 0.0383 (0.0383)  loss_rpn_box_reg: 0.0054 (0.0054)  time: 3.6348  data: 2.1389  max mem: 4517
# Epoch: [0]  [ 10/589]  eta: 0:14:20  lr: 0.000020  loss: 1.6917 (1.7222)  loss_classifier: 1.5063 (1.4935)  loss_box_reg: 0.1726 (0.1950)  loss_objectness: 0.0252 (0.0294)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 1.4870  data: 0.2217  max mem: 5051
# Epoch: [0]  [ 20/589]  eta: 0:13:12  lr: 0.000037  loss: 1.6467 (1.5753)  loss_classifier: 1.4026 (1.3506)  loss_box_reg: 0.1769 (0.1952)  loss_objectness: 0.0217 (0.0255)  loss_rpn_box_reg: 0.0038 (0.0040)  time: 1.2804  data: 0.0318  max mem: 5054
# Epoch: [0]  [ 30/589]  eta: 0:12:41  lr: 0.000054  loss: 1.1183 (1.3415)  loss_classifier: 0.8427 (1.1233)  loss_box_reg: 0.1769 (0.1896)  loss_objectness: 0.0210 (0.0245)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 1.2933  data: 0.0334  max mem: 5056
# Epoch: [0]  [ 40/589]  eta: 0:12:26  lr: 0.000071  loss: 0.5990 (1.1418)  loss_classifier: 0.3820 (0.9249)  loss_box_reg: 0.1770 (0.1882)  loss_objectness: 0.0206 (0.0245)  loss_rpn_box_reg: 0.0037 (0.0042)  time: 1.3244  data: 0.0331  max mem: 5056
# Epoch: [0]  [ 50/589]  eta: 0:12:08  lr: 0.000088  loss: 0.4788 (1.0062)  loss_classifier: 0.2565 (0.7898)  loss_box_reg: 0.1910 (0.1891)  loss_objectness: 0.0206 (0.0234)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 1.3359  data: 0.0329  max mem: 5056
# Epoch: [0]  [ 60/589]  eta: 0:11:48  lr: 0.000105  loss: 0.4478 (0.9211)  loss_classifier: 0.2213 (0.6987)  loss_box_reg: 0.1910 (0.1915)  loss_objectness: 0.0178 (0.0263)  loss_rpn_box_reg: 0.0030 (0.0045)  time: 1.2962  data: 0.0328  max mem: 5056
# Epoch: [0]  [ 70/589]  eta: 0:11:29  lr: 0.000122  loss: 0.3969 (0.8488)  loss_classifier: 0.1994 (0.6293)  loss_box_reg: 0.1752 (0.1904)  loss_objectness: 0.0131 (0.0248)  loss_rpn_box_reg: 0.0029 (0.0043)  time: 1.2701  data: 0.0329  max mem: 5056
# Epoch: [0]  [ 80/589]  eta: 0:11:15  lr: 0.000139  loss: 0.4006 (0.8057)  loss_classifier: 0.1997 (0.5806)  loss_box_reg: 0.1895 (0.1937)  loss_objectness: 0.0119 (0.0269)  loss_rpn_box_reg: 0.0030 (0.0046)  time: 1.2922  data: 0.0334  max mem: 5056
# Epoch: [0]  [ 90/589]  eta: 0:11:01  lr: 0.000156  loss: 0.4088 (0.7643)  loss_classifier: 0.1998 (0.5394)  loss_box_reg: 0.1951 (0.1940)  loss_objectness: 0.0162 (0.0263)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 1.3142  data: 0.0331  max mem: 5056
# Epoch: [0]  [100/589]  eta: 0:10:47  lr: 0.000173  loss: 0.3903 (0.7315)  loss_classifier: 0.1819 (0.5061)  loss_box_reg: 0.1903 (0.1959)  loss_objectness: 0.0120 (0.0251)  loss_rpn_box_reg: 0.0033 (0.0045)  time: 1.3090  data: 0.0325  max mem: 5056
# Epoch: [0]  [110/589]  eta: 0:10:33  lr: 0.000190  loss: 0.4004 (0.7040)  loss_classifier: 0.1829 (0.4786)  loss_box_reg: 0.2035 (0.1968)  loss_objectness: 0.0105 (0.0243)  loss_rpn_box_reg: 0.0030 (0.0043)  time: 1.3088  data: 0.0336  max mem: 5056
# Epoch: [0]  [120/589]  eta: 0:10:20  lr: 0.000207  loss: 0.4057 (0.6758)  loss_classifier: 0.1759 (0.4529)  loss_box_reg: 0.1885 (0.1952)  loss_objectness: 0.0105 (0.0233)  loss_rpn_box_reg: 0.0030 (0.0043)  time: 1.3167  data: 0.0349  max mem: 5056
# Epoch: [0]  [130/589]  eta: 0:10:06  lr: 0.000224  loss: 0.3247 (0.6518)  loss_classifier: 0.1471 (0.4311)  loss_box_reg: 0.1607 (0.1942)  loss_objectness: 0.0091 (0.0223)  loss_rpn_box_reg: 0.0038 (0.0042)  time: 1.3209  data: 0.0353  max mem: 5056
# Epoch: [0]  [140/589]  eta: 0:09:53  lr: 0.000241  loss: 0.3406 (0.6322)  loss_classifier: 0.1577 (0.4125)  loss_box_reg: 0.1726 (0.1941)  loss_objectness: 0.0083 (0.0215)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 1.3115  data: 0.0342  max mem: 5058
# Epoch: [0]  [150/589]  eta: 0:09:38  lr: 0.000258  loss: 0.4088 (0.6179)  loss_classifier: 0.1807 (0.3976)  loss_box_reg: 0.1966 (0.1950)  loss_objectness: 0.0111 (0.0210)  loss_rpn_box_reg: 0.0035 (0.0043)  time: 1.2891  data: 0.0332  max mem: 5058
# Epoch: [0]  [160/589]  eta: 0:09:25  lr: 0.000275  loss: 0.3774 (0.6030)  loss_classifier: 0.1781 (0.3834)  loss_box_reg: 0.1903 (0.1948)  loss_objectness: 0.0099 (0.0205)  loss_rpn_box_reg: 0.0037 (0.0043)  time: 1.2930  data: 0.0334  max mem: 5058
# Epoch: [0]  [170/589]  eta: 0:09:11  lr: 0.000292  loss: 0.3375 (0.5882)  loss_classifier: 0.1436 (0.3698)  loss_box_reg: 0.1776 (0.1941)  loss_objectness: 0.0082 (0.0200)  loss_rpn_box_reg: 0.0036 (0.0043)  time: 1.3086  data: 0.0346  max mem: 5058
# Epoch: [0]  [180/589]  eta: 0:08:58  lr: 0.000309  loss: 0.3458 (0.5778)  loss_classifier: 0.1529 (0.3590)  loss_box_reg: 0.1836 (0.1950)  loss_objectness: 0.0090 (0.0195)  loss_rpn_box_reg: 0.0029 (0.0043)  time: 1.3107  data: 0.0344  max mem: 5058
# Epoch: [0]  [190/589]  eta: 0:08:45  lr: 0.000326  loss: 0.3478 (0.5656)  loss_classifier: 0.1475 (0.3479)  loss_box_reg: 0.1838 (0.1945)  loss_objectness: 0.0068 (0.0190)  loss_rpn_box_reg: 0.0024 (0.0042)  time: 1.3141  data: 0.0341  max mem: 5058
# Epoch: [0]  [200/589]  eta: 0:08:32  lr: 0.000342  loss: 0.3310 (0.5556)  loss_classifier: 0.1407 (0.3381)  loss_box_reg: 0.1808 (0.1945)  loss_objectness: 0.0068 (0.0188)  loss_rpn_box_reg: 0.0025 (0.0042)  time: 1.3187  data: 0.0351  max mem: 5058
# Epoch: [0]  [210/589]  eta: 0:08:18  lr: 0.000359  loss: 0.3302 (0.5454)  loss_classifier: 0.1373 (0.3289)  loss_box_reg: 0.1806 (0.1940)  loss_objectness: 0.0070 (0.0184)  loss_rpn_box_reg: 0.0024 (0.0042)  time: 1.3092  data: 0.0339  max mem: 5058
# Epoch: [0]  [220/589]  eta: 0:08:05  lr: 0.000376  loss: 0.3422 (0.5364)  loss_classifier: 0.1480 (0.3207)  loss_box_reg: 0.1827 (0.1938)  loss_objectness: 0.0066 (0.0178)  loss_rpn_box_reg: 0.0024 (0.0041)  time: 1.3099  data: 0.0330  max mem: 5058
# Epoch: [0]  [230/589]  eta: 0:07:52  lr: 0.000393  loss: 0.3422 (0.5282)  loss_classifier: 0.1480 (0.3132)  loss_box_reg: 0.1827 (0.1936)  loss_objectness: 0.0056 (0.0173)  loss_rpn_box_reg: 0.0024 (0.0041)  time: 1.3168  data: 0.0333  max mem: 5058
# Epoch: [0]  [240/589]  eta: 0:07:39  lr: 0.000410  loss: 0.3369 (0.5221)  loss_classifier: 0.1411 (0.3068)  loss_box_reg: 0.1897 (0.1943)  loss_objectness: 0.0054 (0.0170)  loss_rpn_box_reg: 0.0028 (0.0040)  time: 1.3068  data: 0.0336  max mem: 5058
# Epoch: [0]  [250/589]  eta: 0:07:25  lr: 0.000427  loss: 0.3251 (0.5141)  loss_classifier: 0.1361 (0.2998)  loss_box_reg: 0.1897 (0.1938)  loss_objectness: 0.0044 (0.0166)  loss_rpn_box_reg: 0.0027 (0.0040)  time: 1.3041  data: 0.0330  max mem: 5058
# Epoch: [0]  [260/589]  eta: 0:07:12  lr: 0.000444  loss: 0.3121 (0.5093)  loss_classifier: 0.1304 (0.2942)  loss_box_reg: 0.1885 (0.1945)  loss_objectness: 0.0054 (0.0166)  loss_rpn_box_reg: 0.0025 (0.0039)  time: 1.3048  data: 0.0331  max mem: 5058
# Epoch: [0]  [270/589]  eta: 0:06:59  lr: 0.000461  loss: 0.3105 (0.5031)  loss_classifier: 0.1300 (0.2885)  loss_box_reg: 0.1755 (0.1941)  loss_objectness: 0.0088 (0.0166)  loss_rpn_box_reg: 0.0027 (0.0039)  time: 1.2958  data: 0.0343  max mem: 5058
# Epoch: [0]  [280/589]  eta: 0:06:45  lr: 0.000478  loss: 0.2935 (0.4986)  loss_classifier: 0.1183 (0.2830)  loss_box_reg: 0.1673 (0.1935)  loss_objectness: 0.0096 (0.0178)  loss_rpn_box_reg: 0.0025 (0.0042)  time: 1.3028  data: 0.0344  max mem: 5058
# Epoch: [0]  [290/589]  eta: 0:06:32  lr: 0.000495  loss: 0.3105 (0.4943)  loss_classifier: 0.1228 (0.2782)  loss_box_reg: 0.1740 (0.1940)  loss_objectness: 0.0109 (0.0178)  loss_rpn_box_reg: 0.0029 (0.0043)  time: 1.2916  data: 0.0347  max mem: 5058
# Epoch: [0]  [300/589]  eta: 0:06:18  lr: 0.000512  loss: 0.3049 (0.4880)  loss_classifier: 0.1228 (0.2729)  loss_box_reg: 0.1666 (0.1934)  loss_objectness: 0.0075 (0.0175)  loss_rpn_box_reg: 0.0029 (0.0042)  time: 1.2706  data: 0.0351  max mem: 5058
# Epoch: [0]  [310/589]  eta: 0:06:05  lr: 0.000529  loss: 0.2703 (0.4817)  loss_classifier: 0.1019 (0.2679)  loss_box_reg: 0.1564 (0.1925)  loss_objectness: 0.0057 (0.0172)  loss_rpn_box_reg: 0.0029 (0.0042)  time: 1.2621  data: 0.0338  max mem: 5058
# Epoch: [0]  [320/589]  eta: 0:05:52  lr: 0.000546  loss: 0.2710 (0.4762)  loss_classifier: 0.1019 (0.2631)  loss_box_reg: 0.1564 (0.1919)  loss_objectness: 0.0051 (0.0170)  loss_rpn_box_reg: 0.0024 (0.0042)  time: 1.2777  data: 0.0332  max mem: 5058
# Epoch: [0]  [330/589]  eta: 0:05:39  lr: 0.000563  loss: 0.2823 (0.4739)  loss_classifier: 0.1055 (0.2592)  loss_box_reg: 0.1622 (0.1921)  loss_objectness: 0.0071 (0.0181)  loss_rpn_box_reg: 0.0024 (0.0045)  time: 1.3179  data: 0.0337  max mem: 5058
# Epoch: [0]  [340/589]  eta: 0:05:25  lr: 0.000580  loss: 0.2720 (0.4694)  loss_classifier: 0.1075 (0.2553)  loss_box_reg: 0.1622 (0.1915)  loss_objectness: 0.0104 (0.0182)  loss_rpn_box_reg: 0.0027 (0.0045)  time: 1.3048  data: 0.0332  max mem: 5058
# Epoch: [0]  [350/589]  eta: 0:05:12  lr: 0.000597  loss: 0.2720 (0.4643)  loss_classifier: 0.1075 (0.2511)  loss_box_reg: 0.1516 (0.1907)  loss_objectness: 0.0100 (0.0180)  loss_rpn_box_reg: 0.0023 (0.0045)  time: 1.3027  data: 0.0324  max mem: 5058
# Epoch: [0]  [360/589]  eta: 0:04:59  lr: 0.000614  loss: 0.2822 (0.4595)  loss_classifier: 0.1013 (0.2470)  loss_box_reg: 0.1590 (0.1902)  loss_objectness: 0.0085 (0.0178)  loss_rpn_box_reg: 0.0022 (0.0045)  time: 1.3207  data: 0.0327  max mem: 5058
# Epoch: [0]  [370/589]  eta: 0:04:46  lr: 0.000631  loss: 0.2762 (0.4555)  loss_classifier: 0.0984 (0.2433)  loss_box_reg: 0.1627 (0.1898)  loss_objectness: 0.0118 (0.0178)  loss_rpn_box_reg: 0.0026 (0.0046)  time: 1.2806  data: 0.0331  max mem: 5058
# Epoch: [0]  [380/589]  eta: 0:04:33  lr: 0.000648  loss: 0.2550 (0.4504)  loss_classifier: 0.0923 (0.2394)  loss_box_reg: 0.1485 (0.1890)  loss_objectness: 0.0087 (0.0175)  loss_rpn_box_reg: 0.0025 (0.0045)  time: 1.2792  data: 0.0336  max mem: 5058
# Epoch: [0]  [390/589]  eta: 0:04:20  lr: 0.000665  loss: 0.2450 (0.4453)  loss_classifier: 0.0880 (0.2355)  loss_box_reg: 0.1475 (0.1882)  loss_objectness: 0.0033 (0.0172)  loss_rpn_box_reg: 0.0025 (0.0045)  time: 1.2960  data: 0.0334  max mem: 5058
# Epoch: [0]  [400/589]  eta: 0:04:07  lr: 0.000682  loss: 0.2312 (0.4409)  loss_classifier: 0.0812 (0.2319)  loss_box_reg: 0.1442 (0.1876)  loss_objectness: 0.0030 (0.0169)  loss_rpn_box_reg: 0.0025 (0.0045)  time: 1.2975  data: 0.0327  max mem: 5058
# Epoch: [0]  [410/589]  eta: 0:03:53  lr: 0.000699  loss: 0.2363 (0.4363)  loss_classifier: 0.0848 (0.2285)  loss_box_reg: 0.1432 (0.1867)  loss_objectness: 0.0038 (0.0167)  loss_rpn_box_reg: 0.0024 (0.0045)  time: 1.3109  data: 0.0329  max mem: 5058
# Epoch: [0]  [420/589]  eta: 0:03:40  lr: 0.000716  loss: 0.2634 (0.4326)  loss_classifier: 0.0871 (0.2255)  loss_box_reg: 0.1473 (0.1861)  loss_objectness: 0.0068 (0.0165)  loss_rpn_box_reg: 0.0028 (0.0044)  time: 1.2938  data: 0.0340  max mem: 5058
# Epoch: [0]  [430/589]  eta: 0:03:27  lr: 0.000733  loss: 0.2695 (0.4292)  loss_classifier: 0.1007 (0.2227)  loss_box_reg: 0.1582 (0.1857)  loss_objectness: 0.0051 (0.0163)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 1.2962  data: 0.0336  max mem: 5058
# Epoch: [0]  [440/589]  eta: 0:03:14  lr: 0.000750  loss: 0.2525 (0.4249)  loss_classifier: 0.0926 (0.2197)  loss_box_reg: 0.1385 (0.1846)  loss_objectness: 0.0053 (0.0162)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 1.2886  data: 0.0328  max mem: 5058
# Epoch: [0]  [450/589]  eta: 0:03:01  lr: 0.000767  loss: 0.2333 (0.4209)  loss_classifier: 0.0907 (0.2169)  loss_box_reg: 0.1343 (0.1837)  loss_objectness: 0.0060 (0.0160)  loss_rpn_box_reg: 0.0030 (0.0044)  time: 1.2804  data: 0.0334  max mem: 5058
# Epoch: [0]  [460/589]  eta: 0:02:48  lr: 0.000784  loss: 0.2333 (0.4170)  loss_classifier: 0.0932 (0.2142)  loss_box_reg: 0.1323 (0.1825)  loss_objectness: 0.0054 (0.0159)  loss_rpn_box_reg: 0.0028 (0.0045)  time: 1.3074  data: 0.0334  max mem: 5058
# Epoch: [0]  [470/589]  eta: 0:02:35  lr: 0.000801  loss: 0.1973 (0.4124)  loss_classifier: 0.0724 (0.2111)  loss_box_reg: 0.1136 (0.1811)  loss_objectness: 0.0046 (0.0157)  loss_rpn_box_reg: 0.0025 (0.0045)  time: 1.3111  data: 0.0341  max mem: 5058
# Epoch: [0]  [480/589]  eta: 0:02:22  lr: 0.000818  loss: 0.2112 (0.4089)  loss_classifier: 0.0788 (0.2087)  loss_box_reg: 0.1226 (0.1804)  loss_objectness: 0.0029 (0.0154)  loss_rpn_box_reg: 0.0025 (0.0044)  time: 1.2920  data: 0.0335  max mem: 5058
# Epoch: [0]  [490/589]  eta: 0:02:09  lr: 0.000835  loss: 0.2166 (0.4054)  loss_classifier: 0.0830 (0.2064)  loss_box_reg: 0.1244 (0.1792)  loss_objectness: 0.0033 (0.0154)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 1.2772  data: 0.0334  max mem: 5058
# Epoch: [0]  [500/589]  eta: 0:01:56  lr: 0.000852  loss: 0.1935 (0.4019)  loss_classifier: 0.0790 (0.2041)  loss_box_reg: 0.1125 (0.1782)  loss_objectness: 0.0059 (0.0152)  loss_rpn_box_reg: 0.0034 (0.0044)  time: 1.2974  data: 0.0339  max mem: 5058
# Epoch: [0]  [510/589]  eta: 0:01:43  lr: 0.000869  loss: 0.1994 (0.3985)  loss_classifier: 0.0768 (0.2018)  loss_box_reg: 0.1079 (0.1771)  loss_objectness: 0.0073 (0.0151)  loss_rpn_box_reg: 0.0031 (0.0044)  time: 1.3201  data: 0.0337  max mem: 5058
# Epoch: [0]  [520/589]  eta: 0:01:30  lr: 0.000886  loss: 0.2120 (0.3959)  loss_classifier: 0.0768 (0.1996)  loss_box_reg: 0.1151 (0.1762)  loss_objectness: 0.0096 (0.0155)  loss_rpn_box_reg: 0.0033 (0.0046)  time: 1.2962  data: 0.0335  max mem: 5058
# Epoch: [0]  [530/589]  eta: 0:01:16  lr: 0.000903  loss: 0.1905 (0.3917)  loss_classifier: 0.0692 (0.1970)  loss_box_reg: 0.1138 (0.1747)  loss_objectness: 0.0072 (0.0155)  loss_rpn_box_reg: 0.0027 (0.0045)  time: 1.2698  data: 0.0335  max mem: 5058
# Epoch: [0]  [540/589]  eta: 0:01:03  lr: 0.000920  loss: 0.1696 (0.3884)  loss_classifier: 0.0631 (0.1947)  loss_box_reg: 0.0963 (0.1737)  loss_objectness: 0.0071 (0.0155)  loss_rpn_box_reg: 0.0027 (0.0045)  time: 1.2950  data: 0.0339  max mem: 5058
# Epoch: [0]  [550/589]  eta: 0:00:50  lr: 0.000937  loss: 0.1643 (0.3850)  loss_classifier: 0.0558 (0.1924)  loss_box_reg: 0.0963 (0.1725)  loss_objectness: 0.0074 (0.0156)  loss_rpn_box_reg: 0.0027 (0.0045)  time: 1.3168  data: 0.0331  max mem: 5058
# Epoch: [0]  [560/589]  eta: 0:00:37  lr: 0.000954  loss: 0.1698 (0.3817)  loss_classifier: 0.0653 (0.1903)  loss_box_reg: 0.1028 (0.1714)  loss_objectness: 0.0061 (0.0154)  loss_rpn_box_reg: 0.0020 (0.0045)  time: 1.3143  data: 0.0332  max mem: 5058
# Epoch: [0]  [570/589]  eta: 0:00:24  lr: 0.000971  loss: 0.1764 (0.3779)  loss_classifier: 0.0664 (0.1881)  loss_box_reg: 0.0998 (0.1701)  loss_objectness: 0.0042 (0.0153)  loss_rpn_box_reg: 0.0019 (0.0045)  time: 1.3235  data: 0.0340  max mem: 5058
# Epoch: [0]  [580/589]  eta: 0:00:11  lr: 0.000988  loss: 0.1686 (0.3745)  loss_classifier: 0.0606 (0.1861)  loss_box_reg: 0.0929 (0.1689)  loss_objectness: 0.0034 (0.0151)  loss_rpn_box_reg: 0.0016 (0.0045)  time: 1.3232  data: 0.0340  max mem: 5058
# Epoch: [0]  [588/589]  eta: 0:00:01  lr: 0.001000  loss: 0.1686 (0.3716)  loss_classifier: 0.0606 (0.1844)  loss_box_reg: 0.0921 (0.1679)  loss_objectness: 0.0024 (0.0149)  loss_rpn_box_reg: 0.0019 (0.0044)  time: 1.2661  data: 0.0313  max mem: 5058
# Epoch: [0] Total time: 0:12:47 (1.3039 s / it)
# Test:  [  0/468]  eta: 0:03:20  model_time: 0.1656 (0.1656)  evaluator_time: 0.0032 (0.0032)  time: 0.4275  data: 0.2548  max mem: 5058
# Test:  [100/468]  eta: 0:00:27  model_time: 0.0605 (0.0623)  evaluator_time: 0.0017 (0.0019)  time: 0.0699  data: 0.0044  max mem: 5058
# Test:  [200/468]  eta: 0:00:19  model_time: 0.0615 (0.0626)  evaluator_time: 0.0015 (0.0019)  time: 0.0748  data: 0.0048  max mem: 5058
# Test:  [300/468]  eta: 0:00:12  model_time: 0.0609 (0.0626)  evaluator_time: 0.0017 (0.0018)  time: 0.0729  data: 0.0048  max mem: 5058
# Test:  [400/468]  eta: 0:00:04  model_time: 0.0620 (0.0627)  evaluator_time: 0.0017 (0.0018)  time: 0.0719  data: 0.0046  max mem: 5058
# Test:  [467/468]  eta: 0:00:00  model_time: 0.0616 (0.0627)  evaluator_time: 0.0015 (0.0018)  time: 0.0706  data: 0.0043  max mem: 5058
# Test: Total time: 0:00:34 (0.0731 s / it)
# Averaged stats: model_time: 0.0616 (0.0627)  evaluator_time: 0.0015 (0.0018)
# Accumulating evaluation results...
# DONE (t=0.15s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.773
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.217
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.487
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.611
# Epoch: [1]  [  0/589]  eta: 0:41:34  lr: 0.001000  loss: 0.1566 (0.1566)  loss_classifier: 0.0520 (0.0520)  loss_box_reg: 0.0948 (0.0948)  loss_objectness: 0.0082 (0.0082)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 4.2354  data: 2.7265  max mem: 5058
# Epoch: [1]  [ 10/589]  eta: 0:14:55  lr: 0.001000  loss: 0.1566 (0.1699)  loss_classifier: 0.0571 (0.0636)  loss_box_reg: 0.0948 (0.0981)  loss_objectness: 0.0049 (0.0059)  loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.5472  data: 0.2701  max mem: 5058
# Epoch: [1]  [ 20/589]  eta: 0:13:35  lr: 0.001000  loss: 0.1564 (0.1735)  loss_classifier: 0.0571 (0.0641)  loss_box_reg: 0.0912 (0.1009)  loss_objectness: 0.0039 (0.0060)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2928  data: 0.0294  max mem: 5058
# Epoch: [1]  [ 30/589]  eta: 0:12:56  lr: 0.001000  loss: 0.1788 (0.1887)  loss_classifier: 0.0678 (0.0683)  loss_box_reg: 0.0984 (0.1074)  loss_objectness: 0.0054 (0.0092)  loss_rpn_box_reg: 0.0024 (0.0037)  time: 1.3027  data: 0.0344  max mem: 5058
# Epoch: [1]  [ 40/589]  eta: 0:12:22  lr: 0.001000  loss: 0.1913 (0.1897)  loss_classifier: 0.0771 (0.0698)  loss_box_reg: 0.1007 (0.1083)  loss_objectness: 0.0037 (0.0081)  loss_rpn_box_reg: 0.0024 (0.0035)  time: 1.2684  data: 0.0336  max mem: 5058
# Epoch: [1]  [ 50/589]  eta: 0:11:57  lr: 0.001000  loss: 0.1913 (0.1897)  loss_classifier: 0.0771 (0.0710)  loss_box_reg: 0.0989 (0.1072)  loss_objectness: 0.0035 (0.0082)  loss_rpn_box_reg: 0.0023 (0.0033)  time: 1.2421  data: 0.0325  max mem: 5058
# Epoch: [1]  [ 60/589]  eta: 0:11:43  lr: 0.001000  loss: 0.1550 (0.1857)  loss_classifier: 0.0587 (0.0690)  loss_box_reg: 0.0937 (0.1052)  loss_objectness: 0.0046 (0.0082)  loss_rpn_box_reg: 0.0028 (0.0033)  time: 1.2849  data: 0.0328  max mem: 5058
# Epoch: [1]  [ 70/589]  eta: 0:11:25  lr: 0.001000  loss: 0.1515 (0.1830)  loss_classifier: 0.0585 (0.0687)  loss_box_reg: 0.0847 (0.1031)  loss_objectness: 0.0046 (0.0079)  loss_rpn_box_reg: 0.0028 (0.0032)  time: 1.2940  data: 0.0335  max mem: 5058
# Epoch: [1]  [ 80/589]  eta: 0:11:11  lr: 0.001000  loss: 0.1624 (0.1829)  loss_classifier: 0.0607 (0.0684)  loss_box_reg: 0.0903 (0.1030)  loss_objectness: 0.0058 (0.0080)  loss_rpn_box_reg: 0.0026 (0.0036)  time: 1.2835  data: 0.0333  max mem: 5058
# Epoch: [1]  [ 90/589]  eta: 0:10:56  lr: 0.001000  loss: 0.1735 (0.1839)  loss_classifier: 0.0640 (0.0691)  loss_box_reg: 0.0903 (0.1032)  loss_objectness: 0.0062 (0.0081)  loss_rpn_box_reg: 0.0026 (0.0035)  time: 1.2930  data: 0.0328  max mem: 5058
# Epoch: [1]  [100/589]  eta: 0:10:39  lr: 0.001000  loss: 0.1556 (0.1822)  loss_classifier: 0.0596 (0.0685)  loss_box_reg: 0.0818 (0.1022)  loss_objectness: 0.0044 (0.0082)  loss_rpn_box_reg: 0.0023 (0.0034)  time: 1.2668  data: 0.0328  max mem: 5058
# Epoch: [1]  [110/589]  eta: 0:10:25  lr: 0.001000  loss: 0.1531 (0.1806)  loss_classifier: 0.0585 (0.0678)  loss_box_reg: 0.0863 (0.1015)  loss_objectness: 0.0032 (0.0081)  loss_rpn_box_reg: 0.0023 (0.0033)  time: 1.2653  data: 0.0333  max mem: 5058
# Epoch: [1]  [120/589]  eta: 0:10:12  lr: 0.001000  loss: 0.1623 (0.1834)  loss_classifier: 0.0604 (0.0690)  loss_box_reg: 0.0919 (0.1026)  loss_objectness: 0.0037 (0.0085)  loss_rpn_box_reg: 0.0025 (0.0033)  time: 1.2872  data: 0.0333  max mem: 5058
# Epoch: [1]  [130/589]  eta: 0:09:59  lr: 0.001000  loss: 0.1740 (0.1822)  loss_classifier: 0.0683 (0.0690)  loss_box_reg: 0.0914 (0.1015)  loss_objectness: 0.0069 (0.0084)  loss_rpn_box_reg: 0.0020 (0.0032)  time: 1.3002  data: 0.0338  max mem: 5058
# Epoch: [1]  [140/589]  eta: 0:09:46  lr: 0.001000  loss: 0.1419 (0.1801)  loss_classifier: 0.0561 (0.0678)  loss_box_reg: 0.0868 (0.1008)  loss_objectness: 0.0047 (0.0081)  loss_rpn_box_reg: 0.0019 (0.0033)  time: 1.3187  data: 0.0355  max mem: 5058
# Epoch: [1]  [150/589]  eta: 0:09:33  lr: 0.001000  loss: 0.1413 (0.1772)  loss_classifier: 0.0516 (0.0668)  loss_box_reg: 0.0839 (0.0994)  loss_objectness: 0.0028 (0.0078)  loss_rpn_box_reg: 0.0020 (0.0032)  time: 1.3151  data: 0.0350  max mem: 5058
# Epoch: [1]  [160/589]  eta: 0:09:20  lr: 0.001000  loss: 0.1228 (0.1772)  loss_classifier: 0.0487 (0.0667)  loss_box_reg: 0.0709 (0.0995)  loss_objectness: 0.0020 (0.0078)  loss_rpn_box_reg: 0.0021 (0.0032)  time: 1.3022  data: 0.0343  max mem: 5058
# Epoch: [1]  [170/589]  eta: 0:09:07  lr: 0.001000  loss: 0.1360 (0.1792)  loss_classifier: 0.0513 (0.0675)  loss_box_reg: 0.0773 (0.1001)  loss_objectness: 0.0024 (0.0079)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 1.3033  data: 0.0341  max mem: 5058
# Epoch: [1]  [180/589]  eta: 0:08:54  lr: 0.001000  loss: 0.1360 (0.1773)  loss_classifier: 0.0488 (0.0669)  loss_box_reg: 0.0773 (0.0991)  loss_objectness: 0.0038 (0.0078)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 1.3062  data: 0.0329  max mem: 5058
# Epoch: [1]  [190/589]  eta: 0:08:41  lr: 0.001000  loss: 0.1369 (0.1765)  loss_classifier: 0.0487 (0.0668)  loss_box_reg: 0.0791 (0.0985)  loss_objectness: 0.0038 (0.0078)  loss_rpn_box_reg: 0.0022 (0.0035)  time: 1.3080  data: 0.0329  max mem: 5058
# Epoch: [1]  [200/589]  eta: 0:08:28  lr: 0.001000  loss: 0.1384 (0.1752)  loss_classifier: 0.0521 (0.0663)  loss_box_reg: 0.0793 (0.0978)  loss_objectness: 0.0027 (0.0076)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.3092  data: 0.0338  max mem: 5058
# Epoch: [1]  [210/589]  eta: 0:08:15  lr: 0.001000  loss: 0.1305 (0.1737)  loss_classifier: 0.0495 (0.0654)  loss_box_reg: 0.0789 (0.0975)  loss_objectness: 0.0022 (0.0074)  loss_rpn_box_reg: 0.0016 (0.0034)  time: 1.3165  data: 0.0333  max mem: 5058
# Epoch: [1]  [220/589]  eta: 0:08:02  lr: 0.001000  loss: 0.1365 (0.1725)  loss_classifier: 0.0500 (0.0650)  loss_box_reg: 0.0843 (0.0968)  loss_objectness: 0.0031 (0.0073)  loss_rpn_box_reg: 0.0020 (0.0033)  time: 1.3108  data: 0.0331  max mem: 5058
# Epoch: [1]  [230/589]  eta: 0:07:49  lr: 0.001000  loss: 0.1556 (0.1743)  loss_classifier: 0.0568 (0.0658)  loss_box_reg: 0.0843 (0.0971)  loss_objectness: 0.0054 (0.0080)  loss_rpn_box_reg: 0.0024 (0.0034)  time: 1.3108  data: 0.0333  max mem: 5058
# Epoch: [1]  [240/589]  eta: 0:07:35  lr: 0.001000  loss: 0.1556 (0.1733)  loss_classifier: 0.0627 (0.0655)  loss_box_reg: 0.0841 (0.0965)  loss_objectness: 0.0054 (0.0079)  loss_rpn_box_reg: 0.0023 (0.0034)  time: 1.2895  data: 0.0326  max mem: 5058
# Epoch: [1]  [250/589]  eta: 0:07:22  lr: 0.001000  loss: 0.1564 (0.1750)  loss_classifier: 0.0698 (0.0661)  loss_box_reg: 0.0833 (0.0968)  loss_objectness: 0.0046 (0.0086)  loss_rpn_box_reg: 0.0020 (0.0036)  time: 1.2682  data: 0.0328  max mem: 5058
# Epoch: [1]  [260/589]  eta: 0:07:09  lr: 0.001000  loss: 0.1453 (0.1745)  loss_classifier: 0.0633 (0.0661)  loss_box_reg: 0.0745 (0.0963)  loss_objectness: 0.0056 (0.0085)  loss_rpn_box_reg: 0.0025 (0.0035)  time: 1.2979  data: 0.0330  max mem: 5058
# Epoch: [1]  [270/589]  eta: 0:06:56  lr: 0.001000  loss: 0.1347 (0.1732)  loss_classifier: 0.0521 (0.0658)  loss_box_reg: 0.0726 (0.0955)  loss_objectness: 0.0071 (0.0084)  loss_rpn_box_reg: 0.0019 (0.0035)  time: 1.3007  data: 0.0332  max mem: 5058
# Epoch: [1]  [280/589]  eta: 0:06:42  lr: 0.001000  loss: 0.1399 (0.1732)  loss_classifier: 0.0537 (0.0656)  loss_box_reg: 0.0755 (0.0954)  loss_objectness: 0.0057 (0.0086)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 1.2668  data: 0.0335  max mem: 5058
# Epoch: [1]  [290/589]  eta: 0:06:29  lr: 0.001000  loss: 0.1704 (0.1737)  loss_classifier: 0.0563 (0.0658)  loss_box_reg: 0.0999 (0.0957)  loss_objectness: 0.0057 (0.0087)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 1.2875  data: 0.0336  max mem: 5058
# Epoch: [1]  [300/589]  eta: 0:06:16  lr: 0.001000  loss: 0.1427 (0.1721)  loss_classifier: 0.0508 (0.0652)  loss_box_reg: 0.0820 (0.0948)  loss_objectness: 0.0042 (0.0085)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 1.3008  data: 0.0338  max mem: 5058
# Epoch: [1]  [310/589]  eta: 0:06:02  lr: 0.001000  loss: 0.1240 (0.1716)  loss_classifier: 0.0429 (0.0650)  loss_box_reg: 0.0742 (0.0946)  loss_objectness: 0.0028 (0.0084)  loss_rpn_box_reg: 0.0018 (0.0035)  time: 1.2582  data: 0.0339  max mem: 5058
# Epoch: [1]  [320/589]  eta: 0:05:49  lr: 0.001000  loss: 0.1431 (0.1712)  loss_classifier: 0.0473 (0.0650)  loss_box_reg: 0.0763 (0.0943)  loss_objectness: 0.0044 (0.0084)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 1.2699  data: 0.0341  max mem: 5058
# Epoch: [1]  [330/589]  eta: 0:05:36  lr: 0.001000  loss: 0.1678 (0.1714)  loss_classifier: 0.0696 (0.0652)  loss_box_reg: 0.0871 (0.0944)  loss_objectness: 0.0060 (0.0084)  loss_rpn_box_reg: 0.0023 (0.0035)  time: 1.2996  data: 0.0348  max mem: 5058
# Epoch: [1]  [340/589]  eta: 0:05:23  lr: 0.001000  loss: 0.1624 (0.1712)  loss_classifier: 0.0696 (0.0651)  loss_box_reg: 0.0874 (0.0942)  loss_objectness: 0.0053 (0.0084)  loss_rpn_box_reg: 0.0024 (0.0034)  time: 1.2825  data: 0.0350  max mem: 5058
# Epoch: [1]  [350/589]  eta: 0:05:10  lr: 0.001000  loss: 0.1395 (0.1704)  loss_classifier: 0.0507 (0.0649)  loss_box_reg: 0.0824 (0.0938)  loss_objectness: 0.0036 (0.0084)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 1.2752  data: 0.0342  max mem: 5058
# Epoch: [1]  [360/589]  eta: 0:04:57  lr: 0.001000  loss: 0.1395 (0.1709)  loss_classifier: 0.0498 (0.0649)  loss_box_reg: 0.0845 (0.0942)  loss_objectness: 0.0037 (0.0084)  loss_rpn_box_reg: 0.0018 (0.0034)  time: 1.3058  data: 0.0342  max mem: 5058
# Epoch: [1]  [370/589]  eta: 0:04:44  lr: 0.001000  loss: 0.1557 (0.1702)  loss_classifier: 0.0545 (0.0647)  loss_box_reg: 0.0913 (0.0938)  loss_objectness: 0.0040 (0.0083)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 1.3048  data: 0.0336  max mem: 5058
# Epoch: [1]  [380/589]  eta: 0:04:31  lr: 0.001000  loss: 0.1433 (0.1703)  loss_classifier: 0.0544 (0.0646)  loss_box_reg: 0.0785 (0.0939)  loss_objectness: 0.0038 (0.0084)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 1.2987  data: 0.0333  max mem: 5058
# Epoch: [1]  [390/589]  eta: 0:04:18  lr: 0.001000  loss: 0.1489 (0.1701)  loss_classifier: 0.0548 (0.0647)  loss_box_reg: 0.0754 (0.0937)  loss_objectness: 0.0052 (0.0084)  loss_rpn_box_reg: 0.0022 (0.0034)  time: 1.3225  data: 0.0344  max mem: 5058
# Epoch: [1]  [400/589]  eta: 0:04:05  lr: 0.001000  loss: 0.1320 (0.1693)  loss_classifier: 0.0590 (0.0644)  loss_box_reg: 0.0714 (0.0932)  loss_objectness: 0.0052 (0.0083)  loss_rpn_box_reg: 0.0026 (0.0034)  time: 1.3133  data: 0.0352  max mem: 5058
# Epoch: [1]  [410/589]  eta: 0:03:52  lr: 0.001000  loss: 0.1320 (0.1692)  loss_classifier: 0.0557 (0.0645)  loss_box_reg: 0.0706 (0.0931)  loss_objectness: 0.0056 (0.0083)  loss_rpn_box_reg: 0.0023 (0.0034)  time: 1.2920  data: 0.0352  max mem: 5058
# Epoch: [1]  [420/589]  eta: 0:03:39  lr: 0.001000  loss: 0.1572 (0.1694)  loss_classifier: 0.0683 (0.0646)  loss_box_reg: 0.0927 (0.0931)  loss_objectness: 0.0049 (0.0083)  loss_rpn_box_reg: 0.0022 (0.0034)  time: 1.2882  data: 0.0342  max mem: 5058
# Epoch: [1]  [430/589]  eta: 0:03:26  lr: 0.001000  loss: 0.1553 (0.1691)  loss_classifier: 0.0636 (0.0646)  loss_box_reg: 0.0888 (0.0930)  loss_objectness: 0.0030 (0.0082)  loss_rpn_box_reg: 0.0021 (0.0033)  time: 1.2834  data: 0.0341  max mem: 5058
# Epoch: [1]  [440/589]  eta: 0:03:13  lr: 0.001000  loss: 0.1175 (0.1680)  loss_classifier: 0.0534 (0.0642)  loss_box_reg: 0.0648 (0.0923)  loss_objectness: 0.0022 (0.0082)  loss_rpn_box_reg: 0.0018 (0.0033)  time: 1.2677  data: 0.0336  max mem: 5058
# Epoch: [1]  [450/589]  eta: 0:03:00  lr: 0.001000  loss: 0.1283 (0.1681)  loss_classifier: 0.0506 (0.0643)  loss_box_reg: 0.0691 (0.0924)  loss_objectness: 0.0036 (0.0081)  loss_rpn_box_reg: 0.0018 (0.0033)  time: 1.2689  data: 0.0326  max mem: 5059
# Epoch: [1]  [460/589]  eta: 0:02:47  lr: 0.001000  loss: 0.1583 (0.1678)  loss_classifier: 0.0605 (0.0643)  loss_box_reg: 0.0757 (0.0920)  loss_objectness: 0.0040 (0.0081)  loss_rpn_box_reg: 0.0023 (0.0033)  time: 1.2945  data: 0.0331  max mem: 5059
# Epoch: [1]  [470/589]  eta: 0:02:34  lr: 0.001000  loss: 0.1381 (0.1677)  loss_classifier: 0.0589 (0.0643)  loss_box_reg: 0.0712 (0.0920)  loss_objectness: 0.0043 (0.0081)  loss_rpn_box_reg: 0.0021 (0.0034)  time: 1.3177  data: 0.0330  max mem: 5059
# Epoch: [1]  [480/589]  eta: 0:02:21  lr: 0.001000  loss: 0.1322 (0.1673)  loss_classifier: 0.0467 (0.0641)  loss_box_reg: 0.0778 (0.0918)  loss_objectness: 0.0037 (0.0080)  loss_rpn_box_reg: 0.0020 (0.0034)  time: 1.3274  data: 0.0337  max mem: 5059
# Epoch: [1]  [490/589]  eta: 0:02:08  lr: 0.001000  loss: 0.1286 (0.1666)  loss_classifier: 0.0456 (0.0639)  loss_box_reg: 0.0778 (0.0914)  loss_objectness: 0.0036 (0.0079)  loss_rpn_box_reg: 0.0019 (0.0034)  time: 1.3007  data: 0.0341  max mem: 5059
# Epoch: [1]  [500/589]  eta: 0:01:55  lr: 0.001000  loss: 0.1286 (0.1663)  loss_classifier: 0.0488 (0.0638)  loss_box_reg: 0.0724 (0.0912)  loss_objectness: 0.0040 (0.0079)  loss_rpn_box_reg: 0.0019 (0.0035)  time: 1.2908  data: 0.0339  max mem: 5059
# Epoch: [1]  [510/589]  eta: 0:01:42  lr: 0.001000  loss: 0.1313 (0.1659)  loss_classifier: 0.0463 (0.0635)  loss_box_reg: 0.0749 (0.0910)  loss_objectness: 0.0039 (0.0079)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.3130  data: 0.0342  max mem: 5059
# Epoch: [1]  [520/589]  eta: 0:01:29  lr: 0.001000  loss: 0.1353 (0.1655)  loss_classifier: 0.0463 (0.0633)  loss_box_reg: 0.0764 (0.0909)  loss_objectness: 0.0020 (0.0078)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.2888  data: 0.0344  max mem: 5059
# Epoch: [1]  [530/589]  eta: 0:01:16  lr: 0.001000  loss: 0.1111 (0.1644)  loss_classifier: 0.0431 (0.0629)  loss_box_reg: 0.0700 (0.0903)  loss_objectness: 0.0017 (0.0077)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.2773  data: 0.0340  max mem: 5059
# Epoch: [1]  [540/589]  eta: 0:01:03  lr: 0.001000  loss: 0.1123 (0.1641)  loss_classifier: 0.0473 (0.0628)  loss_box_reg: 0.0693 (0.0902)  loss_objectness: 0.0026 (0.0076)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 1.2815  data: 0.0333  max mem: 5059
# Epoch: [1]  [550/589]  eta: 0:00:50  lr: 0.001000  loss: 0.1604 (0.1645)  loss_classifier: 0.0592 (0.0630)  loss_box_reg: 0.0872 (0.0904)  loss_objectness: 0.0035 (0.0076)  loss_rpn_box_reg: 0.0024 (0.0035)  time: 1.2963  data: 0.0334  max mem: 5059
# Epoch: [1]  [560/589]  eta: 0:00:37  lr: 0.001000  loss: 0.1604 (0.1642)  loss_classifier: 0.0583 (0.0629)  loss_box_reg: 0.0821 (0.0902)  loss_objectness: 0.0045 (0.0076)  loss_rpn_box_reg: 0.0021 (0.0035)  time: 1.3035  data: 0.0339  max mem: 5059
# Epoch: [1]  [570/589]  eta: 0:00:24  lr: 0.001000  loss: 0.1365 (0.1637)  loss_classifier: 0.0496 (0.0627)  loss_box_reg: 0.0705 (0.0900)  loss_objectness: 0.0035 (0.0076)  loss_rpn_box_reg: 0.0014 (0.0034)  time: 1.2963  data: 0.0334  max mem: 5059
# Epoch: [1]  [580/589]  eta: 0:00:11  lr: 0.001000  loss: 0.1396 (0.1640)  loss_classifier: 0.0497 (0.0629)  loss_box_reg: 0.0775 (0.0901)  loss_objectness: 0.0026 (0.0076)  loss_rpn_box_reg: 0.0022 (0.0034)  time: 1.3026  data: 0.0335  max mem: 5059
# Epoch: [1]  [588/589]  eta: 0:00:01  lr: 0.001000  loss: 0.1329 (0.1638)  loss_classifier: 0.0547 (0.0629)  loss_box_reg: 0.0775 (0.0900)  loss_objectness: 0.0029 (0.0076)  loss_rpn_box_reg: 0.0020 (0.0034)  time: 1.2564  data: 0.0311  max mem: 5059
# Epoch: [1] Total time: 0:12:43 (1.2970 s / it)
# Test:  [  0/468]  eta: 0:03:37  model_time: 0.1112 (0.1112)  evaluator_time: 0.0031 (0.0031)  time: 0.4657  data: 0.3472  max mem: 5059
# Test:  [100/468]  eta: 0:00:27  model_time: 0.0610 (0.0619)  evaluator_time: 0.0014 (0.0018)  time: 0.0707  data: 0.0045  max mem: 5059
# Test:  [200/468]  eta: 0:00:19  model_time: 0.0624 (0.0625)  evaluator_time: 0.0014 (0.0018)  time: 0.0758  data: 0.0050  max mem: 5059
# Test:  [300/468]  eta: 0:00:12  model_time: 0.0610 (0.0625)  evaluator_time: 0.0016 (0.0017)  time: 0.0727  data: 0.0053  max mem: 5059
# Test:  [400/468]  eta: 0:00:04  model_time: 0.0612 (0.0624)  evaluator_time: 0.0017 (0.0017)  time: 0.0714  data: 0.0043  max mem: 5059
# Test:  [467/468]  eta: 0:00:00  model_time: 0.0617 (0.0624)  evaluator_time: 0.0015 (0.0017)  time: 0.0705  data: 0.0043  max mem: 5059
# Test: Total time: 0:00:34 (0.0727 s / it)
# Averaged stats: model_time: 0.0617 (0.0624)  evaluator_time: 0.0015 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.836
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.432
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# Epoch: [2]  [  0/589]  eta: 0:34:10  lr: 0.001000  loss: 0.0932 (0.0932)  loss_classifier: 0.0343 (0.0343)  loss_box_reg: 0.0517 (0.0517)  loss_objectness: 0.0058 (0.0058)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 3.4810  data: 1.9530  max mem: 5059
# Epoch: [2]  [ 10/589]  eta: 0:14:47  lr: 0.001000  loss: 0.1326 (0.1442)  loss_classifier: 0.0620 (0.0570)  loss_box_reg: 0.0720 (0.0791)  loss_objectness: 0.0058 (0.0052)  loss_rpn_box_reg: 0.0024 (0.0028)  time: 1.5333  data: 0.2157  max mem: 5059
# Epoch: [2]  [ 20/589]  eta: 0:13:23  lr: 0.001000  loss: 0.1326 (0.1573)  loss_classifier: 0.0503 (0.0583)  loss_box_reg: 0.0720 (0.0815)  loss_objectness: 0.0023 (0.0127)  loss_rpn_box_reg: 0.0025 (0.0049)  time: 1.3089  data: 0.0376  max mem: 5059
# Epoch: [2]  [ 30/589]  eta: 0:12:52  lr: 0.001000  loss: 0.1078 (0.1447)  loss_classifier: 0.0412 (0.0531)  loss_box_reg: 0.0554 (0.0773)  loss_objectness: 0.0038 (0.0105)  loss_rpn_box_reg: 0.0016 (0.0038)  time: 1.2992  data: 0.0334  max mem: 5059
# Epoch: [2]  [ 40/589]  eta: 0:12:29  lr: 0.001000  loss: 0.1195 (0.1427)  loss_classifier: 0.0413 (0.0519)  loss_box_reg: 0.0627 (0.0778)  loss_objectness: 0.0047 (0.0096)  loss_rpn_box_reg: 0.0015 (0.0035)  time: 1.3153  data: 0.0333  max mem: 5059
# Epoch: [2]  [ 50/589]  eta: 0:12:07  lr: 0.001000  loss: 0.1221 (0.1446)  loss_classifier: 0.0462 (0.0543)  loss_box_reg: 0.0643 (0.0783)  loss_objectness: 0.0035 (0.0087)  loss_rpn_box_reg: 0.0018 (0.0033)  time: 1.2979  data: 0.0332  max mem: 5059
# Epoch: [2]  [ 60/589]  eta: 0:11:51  lr: 0.001000  loss: 0.1335 (0.1440)  loss_classifier: 0.0497 (0.0544)  loss_box_reg: 0.0643 (0.0782)  loss_objectness: 0.0030 (0.0083)  loss_rpn_box_reg: 0.0018 (0.0031)  time: 1.3058  data: 0.0332  max mem: 5059
# Epoch: [2]  [ 70/589]  eta: 0:11:35  lr: 0.001000  loss: 0.1057 (0.1387)  loss_classifier: 0.0428 (0.0527)  loss_box_reg: 0.0606 (0.0754)  loss_objectness: 0.0025 (0.0076)  loss_rpn_box_reg: 0.0018 (0.0030)  time: 1.3187  data: 0.0335  max mem: 5059
# Epoch: [2]  [ 80/589]  eta: 0:11:18  lr: 0.001000  loss: 0.1057 (0.1392)  loss_classifier: 0.0433 (0.0527)  loss_box_reg: 0.0640 (0.0761)  loss_objectness: 0.0032 (0.0076)  loss_rpn_box_reg: 0.0017 (0.0029)  time: 1.2925  data: 0.0339  max mem: 5059
# Epoch: [2]  [ 90/589]  eta: 0:11:03  lr: 0.001000  loss: 0.1413 (0.1406)  loss_classifier: 0.0476 (0.0530)  loss_box_reg: 0.0806 (0.0763)  loss_objectness: 0.0044 (0.0079)  loss_rpn_box_reg: 0.0022 (0.0034)  time: 1.2866  data: 0.0334  max mem: 5059
# Epoch: [2]  [100/589]  eta: 0:10:48  lr: 0.001000  loss: 0.1459 (0.1439)  loss_classifier: 0.0531 (0.0540)  loss_box_reg: 0.0816 (0.0785)  loss_objectness: 0.0046 (0.0079)  loss_rpn_box_reg: 0.0025 (0.0034)  time: 1.2971  data: 0.0329  max mem: 5059
# Epoch: [2]  [110/589]  eta: 0:10:33  lr: 0.001000  loss: 0.1355 (0.1448)  loss_classifier: 0.0556 (0.0545)  loss_box_reg: 0.0748 (0.0791)  loss_objectness: 0.0047 (0.0078)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 1.2964  data: 0.0334  max mem: 5059
# Epoch: [2]  [120/589]  eta: 0:10:18  lr: 0.001000  loss: 0.1263 (0.1437)  loss_classifier: 0.0519 (0.0541)  loss_box_reg: 0.0745 (0.0789)  loss_objectness: 0.0031 (0.0074)  loss_rpn_box_reg: 0.0027 (0.0034)  time: 1.2785  data: 0.0339  max mem: 5059
# Epoch: [2]  [130/589]  eta: 0:10:02  lr: 0.001000  loss: 0.1185 (0.1436)  loss_classifier: 0.0513 (0.0545)  loss_box_reg: 0.0638 (0.0787)  loss_objectness: 0.0030 (0.0071)  loss_rpn_box_reg: 0.0018 (0.0033)  time: 1.2575  data: 0.0335  max mem: 5059
# Epoch: [2]  [140/589]  eta: 0:09:49  lr: 0.001000  loss: 0.1164 (0.1424)  loss_classifier: 0.0500 (0.0539)  loss_box_reg: 0.0638 (0.0783)  loss_objectness: 0.0033 (0.0070)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 1.2838  data: 0.0336  max mem: 5059
# Epoch: [2]  [150/589]  eta: 0:09:36  lr: 0.001000  loss: 0.1195 (0.1428)  loss_classifier: 0.0457 (0.0542)  loss_box_reg: 0.0665 (0.0783)  loss_objectness: 0.0034 (0.0071)  loss_rpn_box_reg: 0.0022 (0.0032)  time: 1.3127  data: 0.0340  max mem: 5059
# Epoch: [2]  [160/589]  eta: 0:09:22  lr: 0.001000  loss: 0.1353 (0.1441)  loss_classifier: 0.0538 (0.0548)  loss_box_reg: 0.0694 (0.0790)  loss_objectness: 0.0049 (0.0071)  loss_rpn_box_reg: 0.0022 (0.0032)  time: 1.2916  data: 0.0330  max mem: 5059
# Epoch: [2]  [170/589]  eta: 0:09:07  lr: 0.001000  loss: 0.1357 (0.1458)  loss_classifier: 0.0538 (0.0554)  loss_box_reg: 0.0770 (0.0800)  loss_objectness: 0.0043 (0.0072)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 1.2632  data: 0.0328  max mem: 5059
# Epoch: [2]  [180/589]  eta: 0:08:53  lr: 0.001000  loss: 0.1252 (0.1450)  loss_classifier: 0.0424 (0.0548)  loss_box_reg: 0.0640 (0.0797)  loss_objectness: 0.0025 (0.0073)  loss_rpn_box_reg: 0.0022 (0.0032)  time: 1.2680  data: 0.0335  max mem: 5059
# Epoch: [2]  [190/589]  eta: 0:08:41  lr: 0.001000  loss: 0.1075 (0.1440)  loss_classifier: 0.0393 (0.0543)  loss_box_reg: 0.0601 (0.0791)  loss_objectness: 0.0017 (0.0072)  loss_rpn_box_reg: 0.0021 (0.0034)  time: 1.3003  data: 0.0328  max mem: 5059
# Epoch: [2]  [200/589]  eta: 0:08:27  lr: 0.001000  loss: 0.1142 (0.1430)  loss_classifier: 0.0430 (0.0540)  loss_box_reg: 0.0675 (0.0786)  loss_objectness: 0.0021 (0.0070)  loss_rpn_box_reg: 0.0021 (0.0034)  time: 1.3083  data: 0.0331  max mem: 5059
# Epoch: [2]  [210/589]  eta: 0:08:15  lr: 0.001000  loss: 0.1077 (0.1417)  loss_classifier: 0.0400 (0.0533)  loss_box_reg: 0.0679 (0.0783)  loss_objectness: 0.0020 (0.0068)  loss_rpn_box_reg: 0.0017 (0.0033)  time: 1.3092  data: 0.0335  max mem: 5059
# Epoch: [2]  [220/589]  eta: 0:08:01  lr: 0.001000  loss: 0.1169 (0.1409)  loss_classifier: 0.0385 (0.0529)  loss_box_reg: 0.0692 (0.0781)  loss_objectness: 0.0023 (0.0067)  loss_rpn_box_reg: 0.0015 (0.0032)  time: 1.3068  data: 0.0331  max mem: 5059
# Epoch: [2]  [230/589]  eta: 0:07:49  lr: 0.001000  loss: 0.1135 (0.1402)  loss_classifier: 0.0428 (0.0527)  loss_box_reg: 0.0619 (0.0778)  loss_objectness: 0.0028 (0.0066)  loss_rpn_box_reg: 0.0019 (0.0032)  time: 1.3074  data: 0.0332  max mem: 5059
# Epoch: [2]  [240/589]  eta: 0:07:36  lr: 0.001000  loss: 0.1108 (0.1396)  loss_classifier: 0.0428 (0.0524)  loss_box_reg: 0.0593 (0.0773)  loss_objectness: 0.0032 (0.0066)  loss_rpn_box_reg: 0.0021 (0.0032)  time: 1.3250  data: 0.0325  max mem: 5059
# Epoch: [2]  [250/589]  eta: 0:07:23  lr: 0.001000  loss: 0.1271 (0.1393)  loss_classifier: 0.0464 (0.0524)  loss_box_reg: 0.0675 (0.0772)  loss_objectness: 0.0032 (0.0065)  loss_rpn_box_reg: 0.0018 (0.0032)  time: 1.3166  data: 0.0333  max mem: 5059
# Epoch: [2]  [260/589]  eta: 0:07:09  lr: 0.001000  loss: 0.1261 (0.1392)  loss_classifier: 0.0562 (0.0524)  loss_box_reg: 0.0675 (0.0772)  loss_objectness: 0.0026 (0.0064)  loss_rpn_box_reg: 0.0017 (0.0032)  time: 1.2898  data: 0.0337  max mem: 5059
# Epoch: [2]  [270/589]  eta: 0:06:56  lr: 0.001000  loss: 0.1262 (0.1394)  loss_classifier: 0.0513 (0.0526)  loss_box_reg: 0.0683 (0.0772)  loss_objectness: 0.0035 (0.0064)  loss_rpn_box_reg: 0.0020 (0.0031)  time: 1.2812  data: 0.0333  max mem: 5059
# Epoch: [2]  [280/589]  eta: 0:06:43  lr: 0.001000  loss: 0.1262 (0.1389)  loss_classifier: 0.0422 (0.0523)  loss_box_reg: 0.0761 (0.0771)  loss_objectness: 0.0030 (0.0063)  loss_rpn_box_reg: 0.0021 (0.0031)  time: 1.2903  data: 0.0333  max mem: 5059
# Epoch: [2]  [290/589]  eta: 0:06:29  lr: 0.001000  loss: 0.1094 (0.1391)  loss_classifier: 0.0422 (0.0525)  loss_box_reg: 0.0687 (0.0772)  loss_objectness: 0.0025 (0.0063)  loss_rpn_box_reg: 0.0020 (0.0031)  time: 1.2711  data: 0.0332  max mem: 5059
# Epoch: [2]  [300/589]  eta: 0:06:16  lr: 0.001000  loss: 0.1271 (0.1386)  loss_classifier: 0.0529 (0.0524)  loss_box_reg: 0.0699 (0.0769)  loss_objectness: 0.0032 (0.0062)  loss_rpn_box_reg: 0.0017 (0.0031)  time: 1.2619  data: 0.0337  max mem: 5059
# Epoch: [2]  [310/589]  eta: 0:06:03  lr: 0.001000  loss: 0.1131 (0.1381)  loss_classifier: 0.0492 (0.0524)  loss_box_reg: 0.0617 (0.0766)  loss_objectness: 0.0026 (0.0062)  loss_rpn_box_reg: 0.0013 (0.0030)  time: 1.2805  data: 0.0338  max mem: 5059
# Epoch: [2]  [320/589]  eta: 0:05:50  lr: 0.001000  loss: 0.1131 (0.1380)  loss_classifier: 0.0453 (0.0522)  loss_box_reg: 0.0627 (0.0767)  loss_objectness: 0.0032 (0.0061)  loss_rpn_box_reg: 0.0020 (0.0030)  time: 1.2942  data: 0.0340  max mem: 5059
# Epoch: [2]  [330/589]  eta: 0:05:37  lr: 0.001000  loss: 0.1315 (0.1378)  loss_classifier: 0.0547 (0.0522)  loss_box_reg: 0.0687 (0.0765)  loss_objectness: 0.0034 (0.0061)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 1.3136  data: 0.0329  max mem: 5059
# Epoch: [2]  [340/589]  eta: 0:05:24  lr: 0.001000  loss: 0.1322 (0.1384)  loss_classifier: 0.0560 (0.0525)  loss_box_reg: 0.0707 (0.0770)  loss_objectness: 0.0031 (0.0060)  loss_rpn_box_reg: 0.0018 (0.0030)  time: 1.2942  data: 0.0331  max mem: 5059
# Epoch: [2]  [350/589]  eta: 0:05:10  lr: 0.001000  loss: 0.1316 (0.1383)  loss_classifier: 0.0473 (0.0524)  loss_box_reg: 0.0788 (0.0771)  loss_objectness: 0.0029 (0.0059)  loss_rpn_box_reg: 0.0022 (0.0029)  time: 1.2610  data: 0.0340  max mem: 5059
# Epoch: [2]  [360/589]  eta: 0:04:57  lr: 0.001000  loss: 0.1254 (0.1380)  loss_classifier: 0.0447 (0.0522)  loss_box_reg: 0.0742 (0.0770)  loss_objectness: 0.0026 (0.0059)  loss_rpn_box_reg: 0.0022 (0.0030)  time: 1.2912  data: 0.0335  max mem: 5059
# Epoch: [2]  [370/589]  eta: 0:04:44  lr: 0.001000  loss: 0.1190 (0.1381)  loss_classifier: 0.0442 (0.0523)  loss_box_reg: 0.0706 (0.0770)  loss_objectness: 0.0026 (0.0058)  loss_rpn_box_reg: 0.0028 (0.0030)  time: 1.3049  data: 0.0336  max mem: 5059
# Epoch: [2]  [380/589]  eta: 0:04:31  lr: 0.001000  loss: 0.1190 (0.1376)  loss_classifier: 0.0426 (0.0521)  loss_box_reg: 0.0674 (0.0768)  loss_objectness: 0.0019 (0.0057)  loss_rpn_box_reg: 0.0018 (0.0030)  time: 1.2671  data: 0.0337  max mem: 5059
# Epoch: [2]  [390/589]  eta: 0:04:18  lr: 0.001000  loss: 0.1241 (0.1384)  loss_classifier: 0.0466 (0.0525)  loss_box_reg: 0.0750 (0.0772)  loss_objectness: 0.0010 (0.0058)  loss_rpn_box_reg: 0.0017 (0.0030)  time: 1.2710  data: 0.0341  max mem: 5059
# Epoch: [2]  [400/589]  eta: 0:04:05  lr: 0.001000  loss: 0.1232 (0.1381)  loss_classifier: 0.0490 (0.0524)  loss_box_reg: 0.0736 (0.0770)  loss_objectness: 0.0046 (0.0058)  loss_rpn_box_reg: 0.0020 (0.0030)  time: 1.2854  data: 0.0340  max mem: 5059
# Epoch: [2]  [410/589]  eta: 0:03:52  lr: 0.001000  loss: 0.1167 (0.1374)  loss_classifier: 0.0402 (0.0521)  loss_box_reg: 0.0670 (0.0767)  loss_objectness: 0.0042 (0.0057)  loss_rpn_box_reg: 0.0022 (0.0030)  time: 1.2886  data: 0.0333  max mem: 5059
# Epoch: [2]  [420/589]  eta: 0:03:39  lr: 0.001000  loss: 0.1118 (0.1375)  loss_classifier: 0.0411 (0.0521)  loss_box_reg: 0.0670 (0.0767)  loss_objectness: 0.0024 (0.0057)  loss_rpn_box_reg: 0.0018 (0.0030)  time: 1.3008  data: 0.0331  max mem: 5059
# Epoch: [2]  [430/589]  eta: 0:03:26  lr: 0.001000  loss: 0.1250 (0.1372)  loss_classifier: 0.0442 (0.0519)  loss_box_reg: 0.0754 (0.0767)  loss_objectness: 0.0026 (0.0056)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 1.3017  data: 0.0336  max mem: 5059
# Epoch: [2]  [440/589]  eta: 0:03:13  lr: 0.001000  loss: 0.1264 (0.1378)  loss_classifier: 0.0446 (0.0521)  loss_box_reg: 0.0722 (0.0769)  loss_objectness: 0.0022 (0.0058)  loss_rpn_box_reg: 0.0023 (0.0031)  time: 1.2952  data: 0.0338  max mem: 5059
# Epoch: [2]  [450/589]  eta: 0:03:00  lr: 0.001000  loss: 0.1289 (0.1382)  loss_classifier: 0.0480 (0.0522)  loss_box_reg: 0.0763 (0.0771)  loss_objectness: 0.0032 (0.0058)  loss_rpn_box_reg: 0.0023 (0.0031)  time: 1.2845  data: 0.0337  max mem: 5059
# Epoch: [2]  [460/589]  eta: 0:02:47  lr: 0.001000  loss: 0.1201 (0.1378)  loss_classifier: 0.0461 (0.0521)  loss_box_reg: 0.0661 (0.0769)  loss_objectness: 0.0027 (0.0058)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 1.3061  data: 0.0344  max mem: 5059
# Epoch: [2]  [470/589]  eta: 0:02:34  lr: 0.001000  loss: 0.1208 (0.1379)  loss_classifier: 0.0461 (0.0521)  loss_box_reg: 0.0663 (0.0769)  loss_objectness: 0.0027 (0.0058)  loss_rpn_box_reg: 0.0021 (0.0030)  time: 1.3162  data: 0.0346  max mem: 5059
# Epoch: [2]  [480/589]  eta: 0:02:21  lr: 0.001000  loss: 0.1148 (0.1371)  loss_classifier: 0.0473 (0.0518)  loss_box_reg: 0.0643 (0.0765)  loss_objectness: 0.0023 (0.0057)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 1.3152  data: 0.0341  max mem: 5059
# Epoch: [2]  [490/589]  eta: 0:02:08  lr: 0.001000  loss: 0.1082 (0.1370)  loss_classifier: 0.0365 (0.0517)  loss_box_reg: 0.0624 (0.0766)  loss_objectness: 0.0022 (0.0057)  loss_rpn_box_reg: 0.0017 (0.0030)  time: 1.3258  data: 0.0341  max mem: 5059
# Epoch: [2]  [500/589]  eta: 0:01:55  lr: 0.001000  loss: 0.1167 (0.1375)  loss_classifier: 0.0410 (0.0518)  loss_box_reg: 0.0743 (0.0769)  loss_objectness: 0.0035 (0.0057)  loss_rpn_box_reg: 0.0020 (0.0030)  time: 1.3053  data: 0.0343  max mem: 5059
# Epoch: [2]  [510/589]  eta: 0:01:42  lr: 0.001000  loss: 0.1163 (0.1373)  loss_classifier: 0.0434 (0.0518)  loss_box_reg: 0.0743 (0.0768)  loss_objectness: 0.0038 (0.0057)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 1.2714  data: 0.0345  max mem: 5059
# Epoch: [2]  [520/589]  eta: 0:01:29  lr: 0.001000  loss: 0.0908 (0.1364)  loss_classifier: 0.0360 (0.0514)  loss_box_reg: 0.0548 (0.0764)  loss_objectness: 0.0020 (0.0056)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 1.2892  data: 0.0340  max mem: 5059
# Epoch: [2]  [530/589]  eta: 0:01:16  lr: 0.001000  loss: 0.1070 (0.1363)  loss_classifier: 0.0389 (0.0514)  loss_box_reg: 0.0619 (0.0764)  loss_objectness: 0.0016 (0.0055)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 1.3057  data: 0.0332  max mem: 5059
# ...
# Epoch: [4]  [470/589]  eta: 0:02:34  lr: 0.000050  loss: 0.0907 (0.1071)  loss_classifier: 0.0288 (0.0389)  loss_box_reg: 0.0566 (0.0623)  loss_objectness: 0.0012 (0.0033)  loss_rpn_box_reg: 0.0015 (0.0026)  time: 1.2944  data: 0.0338  max mem: 5059
# Epoch: [4]  [480/589]  eta: 0:02:21  lr: 0.000050  loss: 0.1005 (0.1073)  loss_classifier: 0.0353 (0.0390)  loss_box_reg: 0.0600 (0.0625)  loss_objectness: 0.0022 (0.0033)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.2677  data: 0.0335  max mem: 5059
# Epoch: [4]  [490/589]  eta: 0:02:08  lr: 0.000050  loss: 0.1056 (0.1073)  loss_classifier: 0.0359 (0.0389)  loss_box_reg: 0.0647 (0.0626)  loss_objectness: 0.0021 (0.0033)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.2807  data: 0.0342  max mem: 5059
# Epoch: [4]  [500/589]  eta: 0:01:55  lr: 0.000050  loss: 0.0967 (0.1071)  loss_classifier: 0.0316 (0.0388)  loss_box_reg: 0.0565 (0.0625)  loss_objectness: 0.0015 (0.0033)  loss_rpn_box_reg: 0.0017 (0.0026)  time: 1.3111  data: 0.0340  max mem: 5059
# Epoch: [4]  [510/589]  eta: 0:01:42  lr: 0.000050  loss: 0.0886 (0.1068)  loss_classifier: 0.0316 (0.0387)  loss_box_reg: 0.0548 (0.0623)  loss_objectness: 0.0013 (0.0032)  loss_rpn_box_reg: 0.0016 (0.0026)  time: 1.3001  data: 0.0344  max mem: 5059
# Epoch: [4]  [520/589]  eta: 0:01:29  lr: 0.000050  loss: 0.0763 (0.1063)  loss_classifier: 0.0279 (0.0385)  loss_box_reg: 0.0475 (0.0620)  loss_objectness: 0.0009 (0.0032)  loss_rpn_box_reg: 0.0014 (0.0026)  time: 1.2996  data: 0.0342  max mem: 5059
# Epoch: [4]  [530/589]  eta: 0:01:16  lr: 0.000050  loss: 0.0763 (0.1062)  loss_classifier: 0.0279 (0.0384)  loss_box_reg: 0.0477 (0.0620)  loss_objectness: 0.0013 (0.0032)  loss_rpn_box_reg: 0.0014 (0.0025)  time: 1.3027  data: 0.0339  max mem: 5059
# Epoch: [4]  [540/589]  eta: 0:01:03  lr: 0.000050  loss: 0.0957 (0.1063)  loss_classifier: 0.0326 (0.0385)  loss_box_reg: 0.0556 (0.0621)  loss_objectness: 0.0018 (0.0032)  loss_rpn_box_reg: 0.0017 (0.0025)  time: 1.3117  data: 0.0346  max mem: 5059
# Epoch: [4]  [550/589]  eta: 0:00:50  lr: 0.000050  loss: 0.0955 (0.1062)  loss_classifier: 0.0346 (0.0384)  loss_box_reg: 0.0556 (0.0621)  loss_objectness: 0.0027 (0.0032)  loss_rpn_box_reg: 0.0016 (0.0025)  time: 1.2953  data: 0.0333  max mem: 5059
# Epoch: [4]  [560/589]  eta: 0:00:37  lr: 0.000050  loss: 0.1107 (0.1066)  loss_classifier: 0.0374 (0.0385)  loss_box_reg: 0.0613 (0.0623)  loss_objectness: 0.0026 (0.0032)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.2885  data: 0.0335  max mem: 5059
# Epoch: [4]  [570/589]  eta: 0:00:24  lr: 0.000050  loss: 0.1107 (0.1068)  loss_classifier: 0.0374 (0.0386)  loss_box_reg: 0.0621 (0.0625)  loss_objectness: 0.0024 (0.0032)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.2910  data: 0.0343  max mem: 5059
# Epoch: [4]  [580/589]  eta: 0:00:11  lr: 0.000050  loss: 0.0977 (0.1068)  loss_classifier: 0.0365 (0.0386)  loss_box_reg: 0.0605 (0.0625)  loss_objectness: 0.0022 (0.0032)  loss_rpn_box_reg: 0.0020 (0.0025)  time: 1.3013  data: 0.0340  max mem: 5059
# Epoch: [4]  [588/589]  eta: 0:00:01  lr: 0.000050  loss: 0.0976 (0.1067)  loss_classifier: 0.0363 (0.0385)  loss_box_reg: 0.0602 (0.0625)  loss_objectness: 0.0021 (0.0032)  loss_rpn_box_reg: 0.0020 (0.0025)  time: 1.2380  data: 0.0309  max mem: 5059
# Epoch: [4] Total time: 0:12:44 (1.2986 s / it)
# Test:  [  0/468]  eta: 0:03:50  model_time: 0.1006 (0.1006)  evaluator_time: 0.0023 (0.0023)  time: 0.4927  data: 0.3858  max mem: 5059
# Test:  [100/468]  eta: 0:00:27  model_time: 0.0607 (0.0620)  evaluator_time: 0.0013 (0.0016)  time: 0.0696  data: 0.0046  max mem: 5059
# Test:  [200/468]  eta: 0:00:19  model_time: 0.0619 (0.0627)  evaluator_time: 0.0013 (0.0016)  time: 0.0751  data: 0.0047  max mem: 5059
# Test:  [300/468]  eta: 0:00:12  model_time: 0.0618 (0.0628)  evaluator_time: 0.0013 (0.0016)  time: 0.0725  data: 0.0046  max mem: 5059
# Test:  [400/468]  eta: 0:00:04  model_time: 0.0614 (0.0626)  evaluator_time: 0.0013 (0.0016)  time: 0.0714  data: 0.0049  max mem: 5059
# Test:  [467/468]  eta: 0:00:00  model_time: 0.0617 (0.0626)  evaluator_time: 0.0014 (0.0016)  time: 0.0711  data: 0.0048  max mem: 5059
# Test: Total time: 0:00:34 (0.0729 s / it)
# Averaged stats: model_time: 0.0617 (0.0626)  evaluator_time: 0.0014 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.11s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.621
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.712
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.428
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.627
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.718
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
# Epoch: [5]  [  0/589]  eta: 0:33:21  lr: 0.000050  loss: 0.1868 (0.1868)  loss_classifier: 0.0856 (0.0856)  loss_box_reg: 0.0950 (0.0950)  loss_objectness: 0.0033 (0.0033)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 3.3979  data: 1.8376  max mem: 5059
# Epoch: [5]  [ 10/589]  eta: 0:14:36  lr: 0.000050  loss: 0.0836 (0.1178)  loss_classifier: 0.0413 (0.0459)  loss_box_reg: 0.0426 (0.0654)  loss_objectness: 0.0031 (0.0037)  loss_rpn_box_reg: 0.0023 (0.0028)  time: 1.5130  data: 0.1998  max mem: 5059
# Epoch: [5]  [ 20/589]  eta: 0:13:18  lr: 0.000050  loss: 0.1102 (0.1207)  loss_classifier: 0.0413 (0.0444)  loss_box_reg: 0.0561 (0.0696)  loss_objectness: 0.0024 (0.0038)  loss_rpn_box_reg: 0.0024 (0.0029)  time: 1.3030  data: 0.0349  max mem: 5059
# Epoch: [5]  [ 30/589]  eta: 0:12:42  lr: 0.000050  loss: 0.0864 (0.1128)  loss_classifier: 0.0379 (0.0406)  loss_box_reg: 0.0482 (0.0654)  loss_objectness: 0.0023 (0.0038)  loss_rpn_box_reg: 0.0024 (0.0030)  time: 1.2819  data: 0.0342  max mem: 5059
# Epoch: [5]  [ 40/589]  eta: 0:12:17  lr: 0.000050  loss: 0.0916 (0.1172)  loss_classifier: 0.0329 (0.0416)  loss_box_reg: 0.0544 (0.0667)  loss_objectness: 0.0021 (0.0049)  loss_rpn_box_reg: 0.0016 (0.0040)  time: 1.2805  data: 0.0343  max mem: 5059
# Epoch: [5]  [ 50/589]  eta: 0:11:57  lr: 0.000050  loss: 0.0960 (0.1137)  loss_classifier: 0.0370 (0.0400)  loss_box_reg: 0.0562 (0.0659)  loss_objectness: 0.0021 (0.0043)  loss_rpn_box_reg: 0.0016 (0.0036)  time: 1.2819  data: 0.0337  max mem: 5059
# Epoch: [5]  [ 60/589]  eta: 0:11:41  lr: 0.000050  loss: 0.0888 (0.1128)  loss_classifier: 0.0359 (0.0402)  loss_box_reg: 0.0526 (0.0655)  loss_objectness: 0.0010 (0.0038)  loss_rpn_box_reg: 0.0015 (0.0033)  time: 1.2903  data: 0.0333  max mem: 5059
# Epoch: [5]  [ 70/589]  eta: 0:11:23  lr: 0.000050  loss: 0.0944 (0.1117)  loss_classifier: 0.0389 (0.0395)  loss_box_reg: 0.0545 (0.0654)  loss_objectness: 0.0020 (0.0037)  loss_rpn_box_reg: 0.0015 (0.0031)  time: 1.2768  data: 0.0335  max mem: 5059
# Epoch: [5]  [ 80/589]  eta: 0:11:08  lr: 0.000050  loss: 0.0981 (0.1110)  loss_classifier: 0.0389 (0.0393)  loss_box_reg: 0.0492 (0.0651)  loss_objectness: 0.0023 (0.0036)  loss_rpn_box_reg: 0.0019 (0.0030)  time: 1.2776  data: 0.0336  max mem: 5059
# Epoch: [5]  [ 90/589]  eta: 0:10:56  lr: 0.000050  loss: 0.0853 (0.1084)  loss_classifier: 0.0309 (0.0384)  loss_box_reg: 0.0494 (0.0638)  loss_objectness: 0.0022 (0.0034)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 1.3103  data: 0.0342  max mem: 5059
# Epoch: [5]  [100/589]  eta: 0:10:42  lr: 0.000050  loss: 0.0990 (0.1098)  loss_classifier: 0.0333 (0.0389)  loss_box_reg: 0.0566 (0.0647)  loss_objectness: 0.0022 (0.0034)  loss_rpn_box_reg: 0.0020 (0.0028)  time: 1.3112  data: 0.0337  max mem: 5059
# Epoch: [5]  [110/589]  eta: 0:10:28  lr: 0.000050  loss: 0.1075 (0.1089)  loss_classifier: 0.0363 (0.0386)  loss_box_reg: 0.0658 (0.0643)  loss_objectness: 0.0022 (0.0033)  loss_rpn_box_reg: 0.0018 (0.0027)  time: 1.2975  data: 0.0329  max mem: 5059
# Epoch: [5]  [120/589]  eta: 0:10:14  lr: 0.000050  loss: 0.0939 (0.1088)  loss_classifier: 0.0316 (0.0383)  loss_box_reg: 0.0538 (0.0646)  loss_objectness: 0.0023 (0.0033)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 1.2997  data: 0.0340  max mem: 5059
# Epoch: [5]  [130/589]  eta: 0:10:00  lr: 0.000050  loss: 0.0939 (0.1073)  loss_classifier: 0.0321 (0.0378)  loss_box_reg: 0.0538 (0.0637)  loss_objectness: 0.0013 (0.0032)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 1.2887  data: 0.0345  max mem: 5059
# Epoch: [5]  [140/589]  eta: 0:09:47  lr: 0.000050  loss: 0.0840 (0.1069)  loss_classifier: 0.0280 (0.0378)  loss_box_reg: 0.0524 (0.0632)  loss_objectness: 0.0013 (0.0032)  loss_rpn_box_reg: 0.0010 (0.0028)  time: 1.2972  data: 0.0341  max mem: 5059
# Epoch: [5]  [150/589]  eta: 0:09:34  lr: 0.000050  loss: 0.0840 (0.1059)  loss_classifier: 0.0280 (0.0375)  loss_box_reg: 0.0510 (0.0625)  loss_objectness: 0.0014 (0.0031)  loss_rpn_box_reg: 0.0013 (0.0027)  time: 1.3069  data: 0.0341  max mem: 5059
# Epoch: [5]  [160/589]  eta: 0:09:20  lr: 0.000050  loss: 0.0849 (0.1060)  loss_classifier: 0.0291 (0.0375)  loss_box_reg: 0.0510 (0.0627)  loss_objectness: 0.0010 (0.0031)  loss_rpn_box_reg: 0.0015 (0.0027)  time: 1.2917  data: 0.0348  max mem: 5060
# Epoch: [5]  [170/589]  eta: 0:09:07  lr: 0.000050  loss: 0.0865 (0.1074)  loss_classifier: 0.0302 (0.0379)  loss_box_reg: 0.0554 (0.0635)  loss_objectness: 0.0011 (0.0032)  loss_rpn_box_reg: 0.0015 (0.0028)  time: 1.2947  data: 0.0339  max mem: 5060
# Epoch: [5]  [180/589]  eta: 0:08:53  lr: 0.000050  loss: 0.0913 (0.1081)  loss_classifier: 0.0323 (0.0384)  loss_box_reg: 0.0550 (0.0637)  loss_objectness: 0.0014 (0.0033)  loss_rpn_box_reg: 0.0017 (0.0028)  time: 1.2914  data: 0.0330  max mem: 5060
# Epoch: [5]  [190/589]  eta: 0:08:41  lr: 0.000050  loss: 0.0878 (0.1069)  loss_classifier: 0.0340 (0.0380)  loss_box_reg: 0.0494 (0.0628)  loss_objectness: 0.0019 (0.0032)  loss_rpn_box_reg: 0.0018 (0.0029)  time: 1.3020  data: 0.0337  max mem: 5060
# Epoch: [5]  [200/589]  eta: 0:08:27  lr: 0.000050  loss: 0.0895 (0.1067)  loss_classifier: 0.0337 (0.0381)  loss_box_reg: 0.0500 (0.0626)  loss_objectness: 0.0014 (0.0032)  loss_rpn_box_reg: 0.0015 (0.0028)  time: 1.2996  data: 0.0338  max mem: 5060
# Epoch: [5]  [210/589]  eta: 0:08:14  lr: 0.000050  loss: 0.0958 (0.1080)  loss_classifier: 0.0363 (0.0384)  loss_box_reg: 0.0567 (0.0634)  loss_objectness: 0.0031 (0.0033)  loss_rpn_box_reg: 0.0017 (0.0029)  time: 1.3025  data: 0.0338  max mem: 5060
# Epoch: [5]  [220/589]  eta: 0:08:01  lr: 0.000050  loss: 0.0936 (0.1069)  loss_classifier: 0.0310 (0.0381)  loss_box_reg: 0.0542 (0.0627)  loss_objectness: 0.0023 (0.0032)  loss_rpn_box_reg: 0.0017 (0.0028)  time: 1.3114  data: 0.0340  max mem: 5060
# Epoch: [5]  [230/589]  eta: 0:07:48  lr: 0.000050  loss: 0.0778 (0.1058)  loss_classifier: 0.0269 (0.0377)  loss_box_reg: 0.0480 (0.0621)  loss_objectness: 0.0015 (0.0032)  loss_rpn_box_reg: 0.0016 (0.0028)  time: 1.3017  data: 0.0335  max mem: 5060
# Epoch: [5]  [240/589]  eta: 0:07:35  lr: 0.000050  loss: 0.0852 (0.1057)  loss_classifier: 0.0279 (0.0378)  loss_box_reg: 0.0519 (0.0619)  loss_objectness: 0.0016 (0.0032)  loss_rpn_box_reg: 0.0017 (0.0027)  time: 1.2944  data: 0.0331  max mem: 5060
# Epoch: [5]  [250/589]  eta: 0:07:21  lr: 0.000050  loss: 0.0881 (0.1051)  loss_classifier: 0.0279 (0.0377)  loss_box_reg: 0.0519 (0.0616)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0014 (0.0027)  time: 1.2792  data: 0.0337  max mem: 5060
# Epoch: [5]  [260/589]  eta: 0:07:08  lr: 0.000050  loss: 0.0808 (0.1052)  loss_classifier: 0.0282 (0.0377)  loss_box_reg: 0.0519 (0.0617)  loss_objectness: 0.0010 (0.0031)  loss_rpn_box_reg: 0.0014 (0.0027)  time: 1.2756  data: 0.0342  max mem: 5060
# Epoch: [5]  [270/589]  eta: 0:06:55  lr: 0.000050  loss: 0.0834 (0.1047)  loss_classifier: 0.0302 (0.0374)  loss_box_reg: 0.0520 (0.0615)  loss_objectness: 0.0022 (0.0031)  loss_rpn_box_reg: 0.0014 (0.0026)  time: 1.2862  data: 0.0339  max mem: 5060
# Epoch: [5]  [280/589]  eta: 0:06:42  lr: 0.000050  loss: 0.0925 (0.1052)  loss_classifier: 0.0309 (0.0376)  loss_box_reg: 0.0537 (0.0618)  loss_objectness: 0.0021 (0.0031)  loss_rpn_box_reg: 0.0015 (0.0026)  time: 1.2992  data: 0.0344  max mem: 5060
# Epoch: [5]  [290/589]  eta: 0:06:29  lr: 0.000050  loss: 0.1047 (0.1054)  loss_classifier: 0.0356 (0.0378)  loss_box_reg: 0.0574 (0.0619)  loss_objectness: 0.0023 (0.0031)  loss_rpn_box_reg: 0.0019 (0.0026)  time: 1.3048  data: 0.0344  max mem: 5060
# Epoch: [5]  [300/589]  eta: 0:06:16  lr: 0.000050  loss: 0.0850 (0.1050)  loss_classifier: 0.0316 (0.0375)  loss_box_reg: 0.0526 (0.0618)  loss_objectness: 0.0020 (0.0031)  loss_rpn_box_reg: 0.0018 (0.0026)  time: 1.3048  data: 0.0334  max mem: 5060
# Epoch: [5]  [310/589]  eta: 0:06:03  lr: 0.000050  loss: 0.0708 (0.1040)  loss_classifier: 0.0241 (0.0372)  loss_box_reg: 0.0424 (0.0612)  loss_objectness: 0.0011 (0.0031)  loss_rpn_box_reg: 0.0015 (0.0026)  time: 1.3050  data: 0.0334  max mem: 5060
# Epoch: [5]  [320/589]  eta: 0:05:50  lr: 0.000050  loss: 0.0729 (0.1048)  loss_classifier: 0.0261 (0.0375)  loss_box_reg: 0.0398 (0.0616)  loss_objectness: 0.0012 (0.0031)  loss_rpn_box_reg: 0.0014 (0.0026)  time: 1.2895  data: 0.0335  max mem: 5060
# Epoch: [5]  [330/589]  eta: 0:05:36  lr: 0.000050  loss: 0.0840 (0.1049)  loss_classifier: 0.0285 (0.0376)  loss_box_reg: 0.0530 (0.0616)  loss_objectness: 0.0020 (0.0031)  loss_rpn_box_reg: 0.0012 (0.0026)  time: 1.2647  data: 0.0338  max mem: 5060
# Epoch: [5]  [340/589]  eta: 0:05:23  lr: 0.000050  loss: 0.0842 (0.1047)  loss_classifier: 0.0299 (0.0376)  loss_box_reg: 0.0541 (0.0614)  loss_objectness: 0.0017 (0.0031)  loss_rpn_box_reg: 0.0013 (0.0025)  time: 1.2803  data: 0.0343  max mem: 5060
# Epoch: [5]  [350/589]  eta: 0:05:10  lr: 0.000050  loss: 0.0912 (0.1052)  loss_classifier: 0.0307 (0.0379)  loss_box_reg: 0.0553 (0.0617)  loss_objectness: 0.0018 (0.0031)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.3016  data: 0.0345  max mem: 5060
# Epoch: [5]  [360/589]  eta: 0:04:57  lr: 0.000050  loss: 0.1218 (0.1054)  loss_classifier: 0.0440 (0.0379)  loss_box_reg: 0.0722 (0.0619)  loss_objectness: 0.0020 (0.0031)  loss_rpn_box_reg: 0.0019 (0.0025)  time: 1.2971  data: 0.0341  max mem: 5060
# Epoch: [5]  [370/589]  eta: 0:04:44  lr: 0.000050  loss: 0.0871 (0.1051)  loss_classifier: 0.0319 (0.0378)  loss_box_reg: 0.0520 (0.0616)  loss_objectness: 0.0019 (0.0031)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.2767  data: 0.0341  max mem: 5060
# Epoch: [5]  [380/589]  eta: 0:04:31  lr: 0.000050  loss: 0.0986 (0.1057)  loss_classifier: 0.0353 (0.0380)  loss_box_reg: 0.0548 (0.0620)  loss_objectness: 0.0016 (0.0031)  loss_rpn_box_reg: 0.0018 (0.0025)  time: 1.2772  data: 0.0339  max mem: 5060
# Epoch: [5]  [390/589]  eta: 0:04:18  lr: 0.000050  loss: 0.1092 (0.1060)  loss_classifier: 0.0405 (0.0381)  loss_box_reg: 0.0605 (0.0623)  loss_objectness: 0.0022 (0.0032)  loss_rpn_box_reg: 0.0019 (0.0025)  time: 1.2804  data: 0.0339  max mem: 5060
# Epoch: [5]  [400/589]  eta: 0:04:05  lr: 0.000050  loss: 0.0813 (0.1054)  loss_classifier: 0.0275 (0.0379)  loss_box_reg: 0.0509 (0.0619)  loss_objectness: 0.0017 (0.0031)  loss_rpn_box_reg: 0.0016 (0.0025)  time: 1.2791  data: 0.0342  max mem: 5060
# Epoch: [5]  [410/589]  eta: 0:03:52  lr: 0.000050  loss: 0.0766 (0.1048)  loss_classifier: 0.0254 (0.0376)  loss_box_reg: 0.0476 (0.0616)  loss_objectness: 0.0010 (0.0031)  loss_rpn_box_reg: 0.0014 (0.0025)  time: 1.2786  data: 0.0339  max mem: 5060

# %% [markdown]
# ## Visualization of results
#
# Now that training has finished, let's have a look at what it actually predicts.

# %%
# pick one image from the validation set
img, _ = val_dataset[150]

model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])

prediction

# %% [markdown]
# Printing the prediction shows that we have a list of dictionaries. Each element of the list corresponds to a different image. As we have a single image, there is a single dictionary in the list.
# The dictionary contains the predictions for the image we passed. In this case, we can see that it contains `boxes`, `labels`, and `scores` as fields.
#
# Let's inspect the image and the predicted boxes.
# For that, we need to convert the image, which has been rescaled to 0-1 and had the channels flipped so that we have it in `[C, H, W]` format.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

img_preds = prediction[0]
for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    draw.rectangle(((x1, y1), (x2, y2)), outline="red")
    text = f'{dataset.cat2name[label]}: {score}'
    draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# ## Post-processing
#
# We might notice that there are duplicate detections in the image. Let's post-process the detections with non-maximum suppression.
#
# ** Update: FasterRCNN already has NMS built into it, so you actually do not need to do NMS again.

# %%
img_preds = prediction[0]
keep_idx = batched_nms(boxes=img_preds["boxes"], scores=img_preds["scores"], idxs=img_preds["labels"], iou_threshold=params['IOU_THRESHOLD'])

# %% [markdown]
# Check the predictions again after applying nms.
#
# ** Update: You should not see any difference unless you have specified a lower IoU threshold than the default of 0.5.

# %%
# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Now, let's further filter out the non-confident detections.

# %%
det_threshold = 0.5

# convert the image, which has been rescaled to 0-1 and had the channels flipped
pred_img = Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
draw = ImageDraw.Draw(pred_img)

for i in range(len(img_preds["boxes"])):
    if i in keep_idx:
        x1, y1, x2, y2 = img_preds["boxes"][i]
        label = int(img_preds["labels"][i])
        score = float(img_preds["scores"][i])

        # filter out non-confident detections
        if score > det_threshold:
            draw.rectangle(((x1, y1), (x2, y2)), outline="red")
            text = f'{dataset.cat2name[label]}: {score}'
            draw.text((x1+5, y1+5), text)

display(pred_img)

# %% [markdown]
# Much better! Once you are satisfied with the results, save your model weights.

# %%
# save model weights
save_path = os.path.join(base_folder, "c1_weights.pth")
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ## Evaluation on Validation Set
#
# As a sanity check, let's evaluate the model performance on the validation set

# %%
with open(val_annotation) as json_file:
    val_data = json.load(json_file)

model.eval()
detections = []
with torch.no_grad():
    for image in val_data["images"]:
        img_name = image["file_name"]
        img_id = image["id"]

        img = Image.open(os.path.join(til_root, 'images', img_name)).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)

            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})

# %%
validation_json = os.path.join(base_folder, "validation_preds.json")
with open(validation_json, 'w') as f:
    json.dump(detections, f)

# %%
# Get evaluation score against validation set to make sure your prediction json file is in the correct format
coco_gt = COCO(val_annotation)
coco_dt = coco_gt.loadRes(validation_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# ## Generate Predictions on Test Images

# %%
# You should already have uploaded the testing images onto your google drive.

testing_images_path = os.path.join(base_folder, "c1_test_release.zip") # change this path to the zip file for the test images
# !unzip $testing_images_path

# %%
til_test_root = "/content/c1_test_release/" # extracted testing images path
test_img_root = os.path.join(til_test_root, "images")
img_dir = os.scandir(test_img_root)

# %%
# load model weights (if not using the current trained model)
model.load_state_dict(torch.load(save_path, map_location=device))
model.to(device)
model.eval()

# %% [markdown]
# Let's visualize some predictions on the test images. Run this a few times to visualize different images.

# %%
img = Image.open(next(img_dir).path).convert('RGB')
draw = ImageDraw.Draw(img)
det_threshold = 0.5

# do the prediction
with torch.no_grad():
    img_tensor = transforms.ToTensor()(img)
    img_preds = model([img_tensor.to(device)])[0]

for i in range(len(img_preds["boxes"])):
    x1, y1, x2, y2 = img_preds["boxes"][i]
    label = int(img_preds["labels"][i])
    score = float(img_preds["scores"][i])

    # filter out non-confident detections
    if score > det_threshold:
        draw.rectangle(((x1, y1), (x2, y2)), outline="red")
        text = f'{dataset.cat2name[label]}: {score}'
        draw.text((x1+5, y1+5), text)

display(img)

# %% [markdown]
# ## Submission of Results
#
# Submission json file should be in [COCO format](https://cocodataset.org/#format-results).
#
# ```
# [{
#     "image_id": int,
#     "category_id": int,
#     "bbox": [x,y,width,height],
#     "score": float,
# }]
# ```
#
# Refer to **sample_submission_cv.json** for an example.
#
# For this competition, the metric for evaluation will be mAP @ 0.50:0.95

# %%
# generate detections on the folder of test images (this will be used for submission)
detections = []
with torch.no_grad():
    for image in img_dir:
        img_id = int(image.name.split('.')[0])

        img = Image.open(image.path).convert('RGB')
        img_tensor = transforms.ToTensor()(img)

        preds = model([img_tensor.to(device)])[0]

        for i in range(len(preds["boxes"])):
            x1, y1, x2, y2 = preds["boxes"][i]
            label = int(preds["labels"][i])
            score = float(preds["scores"][i])

            left = int(x1)
            top = int(y1)
            width = int(x2 - x1)
            height = int(y2 - y1)
            detections.append({'image_id':img_id, 'category_id':label, 'bbox':[left, top, width, height], 'score':score})
print(detections)

# %%
test_pred_json = os.path.join(base_folder, "test_preds.json")
with open(test_pred_json, 'w') as f:
    json.dump(detections, f)

# %% [markdown]
# ## Check Your Submission JSON Format (RUN THIS BEFORE SUBMISSION)
#
# Run this function first with the given sample json (change this path for the different challenges) to make sure everything works before you submit. Just need to ensure that there are no errors when you run this. **If you get any errors, check your generated json file.**

# %%
sample_json_path = os.path.join(til_test_root, "c1_test_sample.json")

coco_gt = COCO(sample_json_path)
coco_dt = coco_gt.loadRes(test_pred_json)
cocoEval = COCOeval(cocoGt=coco_gt, cocoDt=coco_dt, iouType='bbox')
cocoEval.evaluate()
cocoEval.accumulate()
cocoEval.summarize()

# %% [markdown]
# If you get an `AssertionError: Results do not correspond to current coco set`, it most likely means that some of the "image_id" are out of range (either 0 or higher than number of test images).
